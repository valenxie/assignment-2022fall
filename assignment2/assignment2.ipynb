# %% [markdown]
# # Assignment 2: Deep Q Learning and Policy Gradient
#
# -----
#
# *2022-2023 fall quarter, CS269 Seminar 5: Reinforcement Learning. Department of Computer Science at University of California, Los Angeles. Course Instructor: Professor Bolei ZHOU. Assignment author: Zhenghao PENG.*

# %% [markdown]
# | Student Name | Student ID |
# | :----: | :----: |
# | Valen Xie | 605948363 |
#
# ------

# %% [markdown]
# Welcome to the assignment 2 of our RL course. This assignment consists of three parts:
#
# * Section 2: Implement Q learning in tabular setting (20 points)
# * Section 3: Implement Deep Q Network with pytorch (30 points)
# * Section 4: Implement policy gradient method REINFORCE with pytorch (30 points)
# * Section 5: Implement policy gradient method with baseline (20 points)
#
# Section 0 and Section 1 set up the dependencies and prepare some useful functions.
#
# The experiments we'll conduct and their expected goals:
#
# 1. Naive Q learning in FrozenLake &emsp; (should solve)
# 2. DQN in CartPole &emsp; (should solve)
# 3. DQN in MetaDrive-Easy &emsp; (should solve)
# 4. DQN in MetaDrive-Hard &emsp; (>50 return)
# 5. Policy Gradient w/o baseline in CartPole (w/ and w/o advantage normalization) &emsp; (should solve)
# 6. Policy Gradient w/o baseline in MetaDrive-Easy &emsp; (should solve)
# 7. Policy Gradient w/ baseline in CartPole (w/ advantage normalization) &emsp; (should solve)
# 8. Policy Gradient w/ baseline in MetaDrive-Easy &emsp; (should solve)
# 9. Policy Gradient w/ baseline in MetaDrive-Hard &emsp; (>50 return)

# %% [markdown]
# ## Section 0: Dependencies
#
# Please install the following dependencies.
#
#
# ### Notes on MetaDrive
#
# MetaDrive is a lightweight driving simulator which we will use for DQN and Policy Gradient methods. It can not be run on M1-chip Mac. We suggest using Colab or Linux for running MetaDrive.
#
# Please ignore this warning from MetaDrive: `WARNING:root:BaseEngine is not launched, fail to sync seed to engine!`
#
# ### Notes on Colab
#
# We have several cells used for installing dependencies for Colab only. Please make sure they are run properly.
#
# You don't need to install python packages again and again after **restarting the runtime**, since the Colab instance still remembers the python envionment after you installing packages for the first time. But you do need to rerun those packages installation script after you **reconnecting to the runtime** (which means Google assigns a new machine to you and thus the python environment is new).

# %%
# !pip install "gym[classic_control,box2d]<0.20.0" seaborn pandas
# !pip install torch
# Out:
# Requirement already satisfied: gym[box2d,classic_control]<0.20.0 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (0.19.0)
# Requirement already satisfied: seaborn in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: pandas in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.18.0 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from gym[box2d,classic_control]<0.20.0) (1.21.6)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from gym[box2d,classic_control]<0.20.0) (1.6.0)
# Requirement already satisfied: pyglet>=1.4.0 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from gym[box2d,classic_control]<0.20.0) (1.5.27)
# Requirement already satisfied: box2d-py~=2.3.5 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from gym[box2d,classic_control]<0.20.0) (2.3.8)
# Requirement already satisfied: typing_extensions in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from seaborn) (4.4.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from pandas) (2022.6)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: six>=1.5 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: torch in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (1.13.0)
# Requirement already satisfied: typing-extensions in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from torch) (4.4.0)

# %%
# Install MetaDrive, a lightweight driving simulator
# !pip install git+https://github.com/metadriverse/metadrive

# Test whether MetaDrive is properly installed. No error means the test is passed.
# !python -m metadrive.examples.profile_metadrive --num-steps 1000
# Out:
# Collecting git+https://github.com/metadriverse/metadrive
#   Cloning https://github.com/metadriverse/metadrive to /private/var/folders/18/mc_7692d7c9665mhcdrpp2v00000gn/T/pip-req-build-tjsicff4
#   Running command git clone --filter=blob:none --quiet https://github.com/metadriverse/metadrive /private/var/folders/18/mc_7692d7c9665mhcdrpp2v00000gn/T/pip-req-build-tjsicff4
#   Resolved https://github.com/metadriverse/metadrive to commit 0f8579c305d3d1a27e35fe494f02d42eabec92fc
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gym==0.19.0 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (0.19.0)
# Requirement already satisfied: numpy in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (1.21.6)
# Requirement already satisfied: matplotlib in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (3.5.3)
# Requirement already satisfied: pandas in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (1.3.5)
# Requirement already satisfied: pygame in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (2.1.2)
# Requirement already satisfied: tqdm in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (4.64.1)
# Requirement already satisfied: yapf in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (0.32.0)
# Requirement already satisfied: seaborn in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (0.12.1)
# Requirement already satisfied: panda3d==1.10.8 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (1.10.8)
# Requirement already satisfied: panda3d-gltf in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (0.13)
# Requirement already satisfied: panda3d-simplepbr in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (0.10)
# Requirement already satisfied: pillow in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (9.3.0)
# Requirement already satisfied: pytest in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (7.2.0)
# Requirement already satisfied: opencv-python-headless in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (4.6.0.66)
# Requirement already satisfied: lxml in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (4.9.1)
# Requirement already satisfied: scipy in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from metadrive-simulator==0.2.5.2) (1.7.3)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from gym==0.19.0->metadrive-simulator==0.2.5.2) (1.6.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from matplotlib->metadrive-simulator==0.2.5.2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from matplotlib->metadrive-simulator==0.2.5.2) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from matplotlib->metadrive-simulator==0.2.5.2) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from matplotlib->metadrive-simulator==0.2.5.2) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from matplotlib->metadrive-simulator==0.2.5.2) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from matplotlib->metadrive-simulator==0.2.5.2) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from pandas->metadrive-simulator==0.2.5.2) (2022.6)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from pytest->metadrive-simulator==0.2.5.2) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from pytest->metadrive-simulator==0.2.5.2) (1.0.1)
# Requirement already satisfied: importlib-metadata>=0.12 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from pytest->metadrive-simulator==0.2.5.2) (5.0.0)
# Requirement already satisfied: iniconfig in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from pytest->metadrive-simulator==0.2.5.2) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from pytest->metadrive-simulator==0.2.5.2) (22.1.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from pytest->metadrive-simulator==0.2.5.2) (2.0.1)
# Requirement already satisfied: typing_extensions in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from seaborn->metadrive-simulator==0.2.5.2) (4.4.0)
# Requirement already satisfied: zipp>=0.5 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest->metadrive-simulator==0.2.5.2) (3.8.1)
# Requirement already satisfied: six>=1.5 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->metadrive-simulator==0.2.5.2) (1.16.0)
# Successfully registered the following environments: ['MetaDrive-validation-v0', 'MetaDrive-10env-v0', 'MetaDrive-100envs-v0', 'MetaDrive-1000envs-v0', 'SafeMetaDrive-validation-v0', 'SafeMetaDrive-10env-v0', 'SafeMetaDrive-100envs-v0', 'SafeMetaDrive-1000envs-v0', 'MARLTollgate-v0', 'MARLBottleneck-v0', 'MARLRoundabout-v0', 'MARLIntersection-v0', 'MARLParkingLot-v0', 'MARLMetaDrive-v0'].
# Start to profile the efficiency of MetaDrive with 1000 maps and ~8 vehicles!
# Finish 100/1000 simulation steps. Time elapse: 0.4667. Average FPS: 214.2718, Average number of vehicles: 11.0000
# Finish 200/1000 simulation steps. Time elapse: 0.9141. Average FPS: 218.7923, Average number of vehicles: 11.0000
# Finish 300/1000 simulation steps. Time elapse: 1.3343. Average FPS: 224.8291, Average number of vehicles: 10.0000
# Finish 400/1000 simulation steps. Time elapse: 1.6622. Average FPS: 240.6498, Average number of vehicles: 9.2000
# Finish 500/1000 simulation steps. Time elapse: 2.0258. Average FPS: 246.8134, Average number of vehicles: 8.8333
# Finish 600/1000 simulation steps. Time elapse: 2.4659. Average FPS: 243.3215, Average number of vehicles: 9.0000
# Finish 700/1000 simulation steps. Time elapse: 2.9074. Average FPS: 240.7676, Average number of vehicles: 9.3750
# Finish 800/1000 simulation steps. Time elapse: 3.4195. Average FPS: 233.9523, Average number of vehicles: 9.4444
# Finish 900/1000 simulation steps. Time elapse: 3.8842. Average FPS: 231.7072, Average number of vehicles: 9.5000
# Finish 1000/1000 simulation steps. Time elapse: 4.7774. Average FPS: 209.3189, Average number of vehicles: 9.5833
# Total Time Elapse: 4.777, average FPS: 209.316, average number of vehicles: 9.583.

# %%
# If you are using Colab, please run the following script EACH time you disconnect from a Runtime.
# !pip install PyOpenGL 
# !apt-get install -y xvfb python-opengl
# !pip install pyvirtualdisplay
# Out:
# Requirement already satisfied: PyOpenGL in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (3.1.6)
# Requirement already satisfied: pyvirtualdisplay in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (3.0)

# %%
# Update(2022-11-03): Fix pyglet compatability issue since it is updated to 2.0.0 recently.
# !pip install "pyglet<2.0.0"
# Out:
# Requirement already satisfied: pyglet<2.0.0 in /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages (1.5.27)

# %%
# If you are using Colab, please run the following script EACH time you restart the Runtime.
import os
os.environ['SDL_VIDEODRIVER']='dummy'

from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start()

# %% [markdown]
# ## Section 1: Building abstract class and helper functions

# %%
# Run this cell without modification

# Import some packages that we need to use
import gym
import numpy as np
import pandas as pd
import seaborn as sns
from collections import deque
import copy
from gym.error import Error
from gym import logger, error
import torch
import torch.nn as nn
import time
from IPython.display import clear_output
from gym.envs.registration import register
import copy
import json
import os
import subprocess
import tempfile
import time
import IPython
import PIL
import pygame


def wait(sleep=0.2):
    clear_output(wait=True)
    time.sleep(sleep)

    
def merge_config(new_config, old_config):
    """Merge the user-defined config with default config"""
    config = copy.deepcopy(old_config)
    if new_config is not None:
        config.update(new_config)
    return config



def test_random_policy(policy, env):
    _acts = set()
    for i in range(1000):
        act = policy(0)
        _acts.add(act)
        assert env.action_space.contains(act), "Out of the bound!"
    if len(_acts) != 1:
        print(
            "[HINT] Though we call self.policy 'random policy', " \
            "we find that generating action randomly at the beginning " \
            "and then fixing it during updating values period lead to better " \
            "performance. Using purely random policy is not even work! " \
            "We encourage you to investigate this issue."
        )
        

# We register a non-slippery version of FrozenLake environment.
try:
    register(
        id='FrozenLakeNotSlippery-v1',
        entry_point='gym.envs.toy_text:FrozenLakeEnv',
        kwargs={'map_name' : '4x4', 'is_slippery': False},
        max_episode_steps=200,
        reward_threshold=0.78, # optimum = .8196
    )
except Error:
    print("The environment is registered already.")

    
def _render_helper(env, mode, sleep=0.1):
    ret = env.render(mode)
    if sleep:
        wait(sleep=sleep)
    return ret
    
    
def animate(img_array):
    """A function that can generate GIF file and show in Notebook."""
    path = tempfile.mkstemp(suffix=".gif")[1]
    images = [PIL.Image.fromarray(frame) for frame in img_array]
    images[0].save(
        path,
        save_all=True,
        append_images=images[1:],
        duration=0.05,
        loop=0
    )
    with open(path, "rb") as f:
        IPython.display.display(
            IPython.display.Image(data=f.read(), format='png'))


def evaluate(policy, num_episodes=1, seed=0, env_name='FrozenLake8x8-v1',
             render=None, existing_env=None, max_episode_length=1000,
             sleep=0.0, verbose=False):
    """This function evaluate the given policy and return the mean episode 
    reward.
    :param policy: a function whose input is the observation
    :param num_episodes: number of episodes you wish to run
    :param seed: the random seed
    :param env_name: the name of the environment
    :param render: a boolean flag indicating whether to render policy
    :return: the averaged episode reward of the given policy.
    """
    if existing_env is None:
        env = gym.make(env_name)
        env.seed(seed)
    else:
        env = existing_env
    rewards = []
    frames = []
    if render: num_episodes = 1
    for i in range(num_episodes):
        obs = env.reset()
        act = policy(obs)
        ep_reward = 0
        for step_count in range(max_episode_length):
            obs, reward, done, info = env.step(act)
            act = policy(obs)
            ep_reward += reward

            if verbose and step_count % 50 == 0:
                print("Evaluating {}/{} episodes. We are in {}/{} steps. Current episode reward: {:.3f}".format(
                    i + 1, num_episodes, step_count + 1, max_episode_length, ep_reward
                ))

            if render:
                frames.append(_render_helper(env, render, sleep))
                wait(sleep=0.05)
            if done:
                break
        rewards.append(ep_reward)
    if render:
        env.close()
    return np.mean(rewards), {"frames": frames}
# Out:
# The environment is registered already.

# %%
# Run this cell without modification

DEFAULT_CONFIG = dict(
    seed=0,
    max_iteration=20000,
    max_episode_length=200,
    evaluate_interval=10,
    evaluate_num_episodes=10,
    learning_rate=0.01,
    gamma=0.8,
    eps=0.3,
    env_name='FrozenLakeNotSlippery-v1'
)

class AbstractTrainer:
    """This is the abstract class for value-based RL trainer. We will inherent
    the specify algorithm's trainer from this abstract class, so that we can
    reuse the codes.
    """

    def __init__(self, config):
        self.config = merge_config(config, DEFAULT_CONFIG)

        # Create the environment
        self.env_name = self.config['env_name']
        self.env = gym.make(self.env_name)

        # Apply the random seed
        self.seed = self.config["seed"]
        np.random.seed(self.seed)
        self.env.seed(self.seed)

        # We set self.obs_dim to the number of possible observation
        # if observation space is discrete, otherwise the number
        # of observation's dimensions. The same to self.act_dim.
        if isinstance(self.env.observation_space, gym.spaces.box.Box):
            assert len(self.env.observation_space.shape) == 1
            self.obs_dim = self.env.observation_space.shape[0]
            self.discrete_obs = False
        elif isinstance(self.env.observation_space,
                        gym.spaces.discrete.Discrete):
            self.obs_dim = self.env.observation_space.n
            self.discrete_obs = True
        else:
            raise ValueError("Wrong observation space!")

        if isinstance(self.env.action_space, gym.spaces.box.Box):
            assert len(self.env.action_space.shape) == 1
            self.act_dim = self.env.action_space.shape[0]
        elif isinstance(self.env.action_space, gym.spaces.discrete.Discrete):
            self.act_dim = self.env.action_space.n
        elif isinstance(self.env.action_space, gym.spaces.MultiDiscrete):
            MetaDrive-Tut-Easy-v0
        else:
            raise ValueError("Wrong action space! {}".format(self.env.action_space))

        self.eps = self.config['eps']


    def process_state(self, state):
        """
        Process the raw observation. For example, we can use this function to
        convert the input state (integer) to a one-hot vector.
        """
        return state

    def compute_action(self, processed_state, eps=None):
        """Compute the action given the processed state."""
        raise NotImplementedError(
            "You need to override the Trainer.compute_action() function.")

    def evaluate(self, num_episodes=50, *args, **kwargs):
        """Use the function you write to evaluate current policy.
        Return the mean episode reward of 50 episodes."""
        if "MetaDrive" in self.env_name:
            kwargs["existing_env"] = self.env
        result, eval_infos = evaluate(self.policy, num_episodes, seed=self.seed,
                          env_name=self.env_name, *args, **kwargs)
        return result, eval_infos

    def policy(self, raw_state, eps=0.0):
        """A wrapper function takes raw_state as input and output action."""
        return self.compute_action(self.process_state(raw_state), eps=eps)
    
    def train(self):
        """Conduct one iteration of learning."""
        raise NotImplementedError("You need to override the "
                                  "Trainer.train() function.")

# %%
# Run this cell without modification

def run(trainer_cls, config=None, reward_threshold=None):
    """Run the trainer and report progress, agnostic to the class of trainer
    :param trainer_cls: A trainer class 
    :param config: A dict
    :param reward_threshold: the reward threshold to break the training
    :return: The trained trainer and a dataframe containing learning progress
    """
    if config is None:
        config = {}
    trainer = trainer_cls(config)
    config = trainer.config
    start = now = time.time()
    stats = []
    total_steps = 0
    
    try:
        for i in range(config['max_iteration'] + 1):
            stat = trainer.train()
            stat = stat or {}
            stats.append(stat)
            if "episode_len" in stat:
                total_steps += stat["episode_len"]
            if i % config['evaluate_interval'] == 0 or \
                    i == config["max_iteration"]:
                reward, _ = trainer.evaluate(
                    config.get("evaluate_num_episodes", 50), 
                    max_episode_length=config.get("max_episode_length", 1000)
                )
                print("({:.1f}s,+{:.1f}s) Iter {}, {}episodic return"
                      " is {:.2f}. {}".format(
                            time.time() - start, 
                            time.time() - now, 
                            i, 
                            "" if total_steps == 0 else "Step {}, ".format(total_steps),
                            reward,
                            {k: round(np.mean(v), 4) for k, v in stat.items() 
                            if not np.isnan(v) and k != "frames"
                            }
                                  if stat else ""
                      ))
                now = time.time()
            if reward_threshold is not None and reward > reward_threshold:
                print("In {} iteration, episodic return {:.3f} is "
                      "greater than reward threshold {}. Congratulation! Now we "
                      "exit the training process.".format(
                    i, reward, reward_threshold))
                break
    except Exception as e:
        print("Error happens during training: ")
        raise e
    finally:
        if hasattr(trainer.env, "close"):
            trainer.env.close()
            print("Environment is closed.")
                
    return trainer, stats

# %% [markdown]
# ## Section 2: Q-Learning
# (20/100 points)
#
# Q-learning is an off-policy algorithm who differs from SARSA in the computing of TD error.
#
# Unlike getting the TD error by running policy to get `next_act` $a'$ and compute:
#
# $r + \gamma Q(s', a') - Q(s, a)$
#
# as in SARSA, in Q-learning we compute the TD error via:
#
# $r + \gamma \max_{a'} Q(s', a') - Q(s, a)$.
#
# The reason we call it "off-policy" is that the next-Q value is not computed for the "behavior policy", instead, it is a "virtural policy" that always takes the best action given current Q values.

# %% [markdown]
# ### Section 2.1: Building Q Learning Trainer

# %%
# Solve the TODOs and remove `pass`

# Managing configurations of your experiments is important for your research.
Q_LEARNING_TRAINER_CONFIG = merge_config(dict(
    eps=0.3,
), DEFAULT_CONFIG)


class QLearningTrainer(AbstractTrainer):
    def __init__(self, config=None):
        config = merge_config(config, Q_LEARNING_TRAINER_CONFIG)
        super(QLearningTrainer, self).__init__(config=config)
        self.gamma = self.config["gamma"]
        self.eps = self.config["eps"]
        self.max_episode_length = self.config["max_episode_length"]
        self.learning_rate = self.config["learning_rate"]

        # build the Q table
        self.table = np.zeros((self.obs_dim, self.act_dim))

    def compute_action(self, obs, eps=None):
        """Implement epsilon-greedy policy

        It is a function that take an integer (state / observation)
        as input and return an interger (action).
        """
        if eps is None:
            eps = self.eps
    
        if np.random.uniform(0, 1) < eps:
            action = np.argmax(self.table[obs])
        else:
            action = self.env.action_space.sample()

        # [TODO] You need to implement the epsilon-greedy policy here.
    
        return action

    def train(self):
        """Conduct one iteration of learning."""
        # [TODO] Q table may be need to be reset to zeros.
        # if you think it should, than do it. If not, then move on.
        pass

        obs = self.env.reset()
        for t in range(self.max_episode_length):
            act = self.compute_action(obs)

            next_obs, reward, done, _ = self.env.step(act)

            # [TODO] compute the TD error based on the next observation and current reward
            td_error = reward+self.gamma*np.max(self.table[next_obs])-self.table[obs][act]

            # [TODO] compute the new Q value
            # hint: use TD error, self.learning_rate and current Q value
            new_value = self.table[obs][act]+self.learning_rate*td_error
            pass

            self.table[obs][act] = new_value
            obs = next_obs
            if done:
                break

# %% [markdown]
# ### Section 2.2: Use Q Learning to train agent in FrozenLake

# %%
# Run this cell without modification

q_learning_trainer, _ = run(
    trainer_cls=QLearningTrainer,
    config=dict(
        max_iteration=5000,
        evaluate_interval=50,
        evaluate_num_episodes=50,
        env_name='FrozenLakeNotSlippery-v1'
    ),
    reward_threshold=0.99
)
# when the episodic return is extremely low, it means a randomly policy solves the one/two of the 50 episodes
# Out:
# (0.0s,+0.0s) Iter 0, episodic return is 0.02.
# (0.0s,+0.0s) Iter 50, episodic return is 0.04.
# (0.1s,+0.0s) Iter 100, episodic return is 0.02.
# (0.1s,+0.0s) Iter 150, episodic return is 0.00.
# (0.1s,+0.0s) Iter 200, episodic return is 0.02.
# (0.1s,+0.0s) Iter 250, episodic return is 0.04.
# (0.1s,+0.0s) Iter 300, episodic return is 0.02.
# (0.2s,+0.0s) Iter 350, episodic return is 0.04.
# (0.2s,+0.0s) Iter 400, episodic return is 0.00.
# (0.2s,+0.0s) Iter 450, episodic return is 0.00.
# (0.2s,+0.0s) Iter 500, episodic return is 0.00.
# (0.2s,+0.0s) Iter 550, episodic return is 0.02.
# (0.3s,+0.0s) Iter 600, episodic return is 0.02.
# (0.3s,+0.0s) Iter 650, episodic return is 0.06.
# (0.3s,+0.0s) Iter 700, episodic return is 0.02.
# (0.3s,+0.0s) Iter 750, episodic return is 0.06.
# (0.3s,+0.0s) Iter 800, episodic return is 0.02.
# (0.4s,+0.0s) Iter 850, episodic return is 0.00.
# (0.4s,+0.0s) Iter 900, episodic return is 0.02.
# (0.4s,+0.0s) Iter 950, episodic return is 0.00.
# (0.4s,+0.0s) Iter 1000, episodic return is 0.02.
# (0.4s,+0.0s) Iter 1050, episodic return is 0.00.
# (0.4s,+0.0s) Iter 1100, episodic return is 0.00.
# (0.5s,+0.0s) Iter 1150, episodic return is 0.02.
# (0.5s,+0.0s) Iter 1200, episodic return is 0.00.
# (0.5s,+0.0s) Iter 1250, episodic return is 0.00.
# (0.5s,+0.0s) Iter 1300, episodic return is 0.02.
# (0.5s,+0.0s) Iter 1350, episodic return is 0.02.
# (0.6s,+0.0s) Iter 1400, episodic return is 0.02.
# (0.6s,+0.0s) Iter 1450, episodic return is 0.00.
# (0.6s,+0.0s) Iter 1500, episodic return is 0.00.
# (0.6s,+0.0s) Iter 1550, episodic return is 0.02.
# (0.6s,+0.0s) Iter 1600, episodic return is 0.00.
# (0.7s,+0.0s) Iter 1650, episodic return is 0.00.
# (0.7s,+0.0s) Iter 1700, episodic return is 0.02.
# (0.7s,+0.0s) Iter 1750, episodic return is 0.02.
# (0.7s,+0.0s) Iter 1800, episodic return is 0.06.
# (0.7s,+0.0s) Iter 1850, episodic return is 0.02.
# (0.7s,+0.0s) Iter 1900, episodic return is 0.00.
# (0.8s,+0.0s) Iter 1950, episodic return is 0.00.
# (0.8s,+0.0s) Iter 2000, episodic return is 0.04.
# (0.8s,+0.0s) Iter 2050, episodic return is 0.00.
# (0.8s,+0.0s) Iter 2100, episodic return is 0.02.
# (0.8s,+0.0s) Iter 2150, episodic return is 0.00.
# (0.9s,+0.0s) Iter 2200, episodic return is 0.02.
# (0.9s,+0.0s) Iter 2250, episodic return is 0.04.
# (0.9s,+0.0s) Iter 2300, episodic return is 0.04.
# (0.9s,+0.0s) Iter 2350, episodic return is 0.02.
# (0.9s,+0.0s) Iter 2400, episodic return is 0.00.
# (1.0s,+0.0s) Iter 2450, episodic return is 0.00.
# (1.0s,+0.0s) Iter 2500, episodic return is 0.00.
# (1.0s,+0.0s) Iter 2550, episodic return is 0.02.
# (1.0s,+0.0s) Iter 2600, episodic return is 0.02.
# (1.0s,+0.0s) Iter 2650, episodic return is 0.02.
# (1.1s,+0.0s) Iter 2700, episodic return is 0.00.
# (1.1s,+0.0s) Iter 2750, episodic return is 0.02.
# (1.1s,+0.0s) Iter 2800, episodic return is 0.02.
# (1.1s,+0.0s) Iter 2850, episodic return is 0.00.
# (1.1s,+0.0s) Iter 2900, episodic return is 0.00.
# (1.1s,+0.0s) Iter 2950, episodic return is 0.00.
# (1.2s,+0.0s) Iter 3000, episodic return is 0.00.
# (1.2s,+0.0s) Iter 3050, episodic return is 0.04.
# (1.2s,+0.0s) Iter 3100, episodic return is 0.02.
# (1.2s,+0.0s) Iter 3150, episodic return is 0.00.
# (1.2s,+0.0s) Iter 3200, episodic return is 0.00.
# (1.3s,+0.0s) Iter 3250, episodic return is 0.00.
# (1.3s,+0.0s) Iter 3300, episodic return is 0.00.
# (1.3s,+0.0s) Iter 3350, episodic return is 0.04.
# (1.3s,+0.0s) Iter 3400, episodic return is 0.00.
# (1.3s,+0.0s) Iter 3450, episodic return is 0.00.
# (1.4s,+0.0s) Iter 3500, episodic return is 0.02.
# (1.4s,+0.0s) Iter 3550, episodic return is 0.00.
# (1.4s,+0.0s) Iter 3600, episodic return is 0.02.
# (1.4s,+0.0s) Iter 3650, episodic return is 0.00.
# (1.4s,+0.0s) Iter 3700, episodic return is 0.02.
# (1.4s,+0.0s) Iter 3750, episodic return is 0.00.
# (1.5s,+0.0s) Iter 3800, episodic return is 0.02.
# (1.5s,+0.0s) Iter 3850, episodic return is 0.02.
# (1.5s,+0.0s) Iter 3900, episodic return is 0.00.
# (1.5s,+0.0s) Iter 3950, episodic return is 0.02.
# (1.5s,+0.0s) Iter 4000, episodic return is 0.00.
# (1.6s,+0.0s) Iter 4050, episodic return is 0.00.
# (1.6s,+0.0s) Iter 4100, episodic return is 0.00.
# (1.6s,+0.0s) Iter 4150, episodic return is 0.00.
# (1.6s,+0.0s) Iter 4200, episodic return is 0.04.
# (1.6s,+0.0s) Iter 4250, episodic return is 0.06.
# (1.7s,+0.0s) Iter 4300, episodic return is 0.06.
# (1.7s,+0.0s) Iter 4350, episodic return is 0.02.
# (1.7s,+0.0s) Iter 4400, episodic return is 0.00.
# (1.7s,+0.0s) Iter 4450, episodic return is 0.00.
# (1.7s,+0.0s) Iter 4500, episodic return is 0.00.
# (1.8s,+0.0s) Iter 4550, episodic return is 0.02.
# (1.8s,+0.0s) Iter 4600, episodic return is 0.04.
# (1.8s,+0.0s) Iter 4650, episodic return is 0.00.
# (1.8s,+0.0s) Iter 4700, episodic return is 0.02.
# (1.8s,+0.0s) Iter 4750, episodic return is 0.04.
# (1.8s,+0.0s) Iter 4800, episodic return is 0.02.
# (1.9s,+0.0s) Iter 4850, episodic return is 0.02.
# (1.9s,+0.0s) Iter 4900, episodic return is 0.02.
# (1.9s,+0.0s) Iter 4950, episodic return is 0.02.
# (1.9s,+0.0s) Iter 5000, episodic return is 0.00.
# Environment is closed.

# %%
# Run this cell without modification

# Render the learned behavior
_ = evaluate(
    policy=q_learning_trainer.policy, 
    num_episodes=1, 
    env_name=q_learning_trainer.env_name,
    render="human",  # Visualize the behavior here in the cell 
    sleep=0.5  # The time interval between two rendering frames
)

# %% [markdown]
# ## Section 3: Implement Deep Q Learning in Pytorch
#
# (30 / 100 points)
#
# In this section, we will implement a basic neural network and Deep Q Learning with Pytorch, a powerful deep learning framework.
# Before start, you need to make sure using `pip install torch` to install it (see Section 0).
#
# If you are not familiar with Pytorch, we suggest you to go through pytorch official quickstart tutorials:
# 1. [quickstart](https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html)
# 2. [tutorial on RL](https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html)
#
# Different from the Q learning in Section 2, we will implement Deep Q Network (DQN) in this section. The main differences are summarized as follows:
#
# **DQN requires an experience replay memory to store the transitions.** A replay memory is implemented in the following `ExperienceReplayMemory` class. It contains a certain amount of transitions: `(s_t, a_t, r_t, s_t+1, done_t)`. When the memory is full, the earliest transition is discarded to store the latest one.
#
# The introduction of replay memory increases the sample efficiency (since each transition might be used multiple times) when solving complex task. However, you may find it learn slowly in this assignment since the CartPole-v0 is a relatively easy environment.
#
#
# **DQN has a delayed-updating target network.** DQN maintains another neural network called the target network that has identical structure of the Q network. After a certain amount of steps has been taken, the target network copies the parameters of the Q network to itself. Normally, the update of target network is much less frequent than the update of the Q network, since the Q network is updated in each step.
#
# The reason to leverage the target network is to stabilize the estimation of the TD error. In DQN, the TD error is evaluated as:
#
# $$(r_t + \gamma \max_{a_{t+1}} Q^{target}(s_{t+1}, a_{t+1}) - Q(s_t, a_t))$$
#
# The Q value of the next state is estimated by the target network, not the Q network that is being updated. This mechanism can reduce the variance of gradient because the next Q values is not influenced by the update of current Q network.

# %% [markdown]
# ### Section 3.1: Build DQN trainer

# %%
# Solve the TODOs and remove `pass`

from collections import deque
import random

class ExperienceReplayMemory:
    """Store and sample the transitions"""
    def __init__(self, capacity):
        # deque is a useful class which acts like a list but only contain
        # finite elements. When adding new element into the deque will make deque full with 
        # `maxlen` elements, the oldest element (the index 0 element) will be removed.
        
        # [TODO] uncomment next line. 
        self.memory = deque(maxlen=capacity)
        pass

    def push(self, transition):
        self.memory.append(transition)

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

# %%
# Solve the TODOs and remove `pass`

class PytorchModel(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_units=100):
        super(PytorchModel, self).__init__()
        
        print("Num inputs: {}, Num actions: {}".format(num_inputs, num_actions))
        
        # [TODO] Build a nn.Sequential object as the neural network with two layers.
        # The first hidden layer has `hidden_units` hidden units, followed by
        # a ReLU activation function.
        # The second hidden layer takes `hidden_units`-dimensional vector as input
        # and output another `hidden_units`-dimensional vector, followed by ReLU activation.
        # The third layer take the activation vector from the second hidden layer, who has
        # `hidden_units` elements, as input and return `num_actions` values.
        model = torch.nn.Sequential(
          torch.nn.Linear(num_inputs,hidden_units),
          torch.nn.ReLU(),
          torch.nn.Linear(hidden_units,hidden_units),
          torch.nn.ReLU(),
          torch.nn.Linear(hidden_units,num_actions)
        )
        self.action_value = model
        pass


    def forward(self, obs):
        return self.action_value(obs)
    
# Test
test_pytorch_model = PytorchModel(num_inputs=3, num_actions=7, hidden_units=123)
assert isinstance(test_pytorch_model.action_value, nn.Module)
assert len(test_pytorch_model.state_dict()) == 6
assert test_pytorch_model.state_dict()["action_value.0.weight"].shape == (123, 3)
print("Name of each parameter vectors: ", test_pytorch_model.state_dict().keys())

print("Test passed!")
# Out:
# Num inputs: 3, Num actions: 7
# Name of each parameter vectors:  odict_keys(['action_value.0.weight', 'action_value.0.bias', 'action_value.2.weight', 'action_value.2.bias', 'action_value.4.weight', 'action_value.4.bias'])
# Test passed!

# %%
# Solve the TODOs and remove `pass`

DQN_CONFIG = merge_config(dict(
    parameter_std=0.01,
    learning_rate=0.01,
    hidden_dim=100,
    clip_norm=1.0,
    clip_gradient=True,
    max_iteration=1000,
    max_episode_length=1000,
    evaluate_interval=100,
    gamma=0.99,
    eps=0.3,
    memory_size=50000,
    learn_start=5000,
    batch_size=32,
    target_update_freq=500,  # in steps
    learn_freq=1,  # in steps
    n=1,
    env_name="CartPole-v0",
), Q_LEARNING_TRAINER_CONFIG)


def to_tensor(x):
    """A helper function to transform a numpy array to a Pytorch Tensor"""
    if isinstance(x, np.ndarray):
        x = torch.from_numpy(x).type(torch.float32)
    assert isinstance(x, torch.Tensor)
    if x.dim() == 3 or x.dim() == 1:
        x = x.unsqueeze(0)
    assert x.dim() == 2 or x.dim() == 4, x.shape
    return x


class DQNTrainer(AbstractTrainer):
    def __init__(self, config):
        config = merge_config(config, DQN_CONFIG)
        self.learning_rate = config["learning_rate"]
        super().__init__(config)

        self.memory = ExperienceReplayMemory(config["memory_size"])
        
        self.learn_start = config["learn_start"]
        self.batch_size = config["batch_size"]
        self.target_update_freq = config["target_update_freq"]
        self.clip_norm = config["clip_norm"]
        self.hidden_dim = config["hidden_dim"]
        self.max_episode_length = self.config["max_episode_length"]
        self.learning_rate = self.config["learning_rate"]
        self.gamma = self.config["gamma"]
        self.n = self.config["n"]

        
        self.step_since_update = 0
        self.total_step = 0
        
        # You need to setup the parameter for your function approximator.
        self.initialize_parameters()

    def initialize_parameters(self):
        self.network = None
        print("Setting up self.network with obs dim: {} and action dim: {}".format(self.obs_dim, self.act_dim))
        self.network = PytorchModel(self.obs_dim, self.act_dim)

        self.network.eval()
        self.network.share_memory()

        # [TODO] Uncomment next few lines
        # Initialize target network, which is identical to self.network,
        # and should have the same weights with self.network. So you should
        # put the weights of self.network into self.target_network.
        
        self.target_network = PytorchModel(self.obs_dim, self.act_dim)
        self.target_network.load_state_dict(self.network.state_dict())
        pass

        self.target_network.eval()

        # Build Adam optimizer and MSE Loss.
        # [TODO] Uncomment next few lines
        self.optimizer = torch.optim.Adam(
            self.network.parameters(), lr=self.learning_rate
        )
        self.loss = nn.MSELoss()
        pass
        
    def process_state(self, state):
        """Preprocess the state (observation).

        If the environment provides discrete observation (state), transform
        it to one-hot form. For example, the environment FrozenLake-v0
        provides an integer in [0, ..., 15] denotes the 16 possible states.
        We transform it to one-hot style:

        original state 0 -> one-hot vector [1, 0, 0, 0, 0, 0, 0, 0, ...]
        original state 1 -> one-hot vector [0, 1, 0, 0, 0, 0, 0, 0, ...]
        original state 15 -> one-hot vector [0, ..., 0, 0, 0, 0, 0, 1]

        If the observation space is continuous, then you should do nothing.
        """
        if not self.discrete_obs:
            return state
        else:
            new_state = np.zeros((self.obs_dim,))
            new_state[state] = 1
        return new_state
    
    def compute_values(self, processed_state):
        """Compute the value for each potential action. Note that you
        should NOT preprocess the state here."""
        values = self.network(processed_state).detach().numpy()
        return values
        
    def compute_action(self, processed_state, eps=None):
        """Compute the action given the state. Note that the input
        is the processed state."""

        values = self.compute_values(processed_state)
        assert values.ndim == 1, values.shape

        if eps is None:
            eps = self.eps

        if np.random.uniform(0, 1) < eps:
            action = self.env.action_space.sample()
        else:
            action = np.argmax(values)
        return action

    def train(self):
        s = self.env.reset()
        processed_s = self.process_state(s)
        act = self.compute_action(processed_s)
        stat = {"loss": [], "success_rate": np.nan}

        for t in range(self.max_episode_length):
            next_state, reward, done, info = self.env.step(act)
            next_processed_s = self.process_state(next_state)

            # Push the transition into memory.
            self.memory.push(
                (processed_s, act, reward, next_processed_s, done)
            )

            processed_s = next_processed_s
            act = self.compute_action(next_processed_s)
            self.step_since_update += 1
            self.total_step += 1

            if done:
                # print("INFO: ", info)
                if "arrive_dest" in info:
                    stat["success_rate"] = info["arrive_dest"]
                break
                
            if t % self.config["learn_freq"] != 0:
                # It's not necessary to update in each step.
                continue

            if len(self.memory) < self.learn_start:
                continue
            elif len(self.memory) == self.learn_start:
                print("Current memory contains {} transitions, "
                      "start learning!".format(self.learn_start))

            batch = self.memory.sample(self.batch_size)

            # Transform a batch of state / action / .. into a tensor.
            state_batch = to_tensor(
                np.stack([transition[0] for transition in batch])
            )
            action_batch = to_tensor(
                np.stack([transition[1] for transition in batch])
            )
            reward_batch = to_tensor(
                np.stack([transition[2] for transition in batch])
            )
            next_state_batch = torch.stack(
                [transition[3] for transition in batch]
            )
            done_batch = to_tensor(
                np.stack([transition[4] for transition in batch])
            )

            with torch.no_grad():
                # [TODO] Compute the Q values of next states
                Q_t_plus_one = self.target_network(next_state_batch).detach().max(1)[0]
                pass
                
                assert isinstance(Q_t_plus_one, torch.Tensor)
                assert Q_t_plus_one.dim() == 1
                
                # [TODO] Compute the target value of Q
                Q_target = (reward_batch + self.gamma * Q_t_plus_one * (1 - done_batch))
                #use 1 - done_batch to get maximum
                Q_target = Q_target.view(self.batch_size,)
                #view reshapes a 2-d array
                
                assert Q_target.shape == (self.batch_size,)
            
            # Collect the Q values in batch.
            self.network.train()
            q_out = self.network(state_batch)
            assert q_out.dim() == 2
            Q_t = q_out.gather(1, action_batch.long().view(-1, 1)).squeeze(-1)
    
            assert Q_t.shape == Q_target.shape

            # Update the network
            self.optimizer.zero_grad()
            loss = self.loss(input=Q_t, target=Q_target)
            loss_value = loss.item()
            stat['loss'].append(loss_value)
            loss.backward()
            
            # [TODO] Gradient clipping. Uncomment next line
            nn.utils.clip_grad_norm_(self.network.parameters(), self.clip_norm)
            pass
            
            self.optimizer.step()
            self.network.eval()

        if len(self.memory) >= self.learn_start and \
                self.step_since_update > self.target_update_freq:
            print("{} steps has passed since last update. Now update the"
                  " parameter of the behavior policy. Current step: {}".format(
                self.step_since_update, self.total_step
            ))
            self.step_since_update = 0
            # [TODO] Copy the weights of self.network to self.target_network.
            self.target_network.load_state_dict(self.network.state_dict())
            # use state_dict to access weight
            
            self.target_network.eval()
            
        ret = {"loss": np.mean(stat["loss"]), "episode_len": t}
        if "success_rate" in stat:
            ret["success_rate"] = stat["success_rate"]
        return ret

    def process_state(self, state):
        return torch.from_numpy(state).type(torch.float32)
    
    def save(self, loc="model.pt"):
        torch.save(self.network.state_dict(), loc)
        
    def load(self, loc="model.pt"):
        self.network.load_state_dict(torch.load(loc))

# %% [markdown]
# ### Section 3.2: Test DQN trainer

# %%
# Run this cell without modification

# Build the test trainer.
test_trainer = DQNTrainer({})

# Test compute_values
fake_state = test_trainer.env.observation_space.sample()
processed_state = test_trainer.process_state(fake_state)
assert processed_state.shape == (test_trainer.obs_dim, ), processed_state.shape
values = test_trainer.compute_values(processed_state)
assert values.shape == (test_trainer.act_dim, ), values.shape

test_trainer.train()
print("Now your codes should be bug-free.")

_ = run(DQNTrainer, dict(
    max_iteration=20,
    evaluate_interval=10, 
    learn_start=100,
    env_name="CartPole-v0",
))

test_trainer.save("test_trainer.pt")
test_trainer.load("test_trainer.pt")

print("Test passed!")
# Out:
# Setting up self.network with obs dim: 4 and action dim: 2
# Num inputs: 4, Num actions: 2
# Num inputs: 4, Num actions: 2
# Now your codes should be bug-free.
# Setting up self.network with obs dim: 4 and action dim: 2
# Num inputs: 4, Num actions: 2
# Num inputs: 4, Num actions: 2
# (0.0s,+0.0s) Iter 0, Step 25, episodic return is 26.50. {'episode_len': 25.0}
# Current memory contains 100 transitions, start learning!
# /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (0.4s,+0.3s) Iter 10, Step 216, episodic return is 9.40. {'loss': 0.0008, 'episode_len': 23.0}
# (0.6s,+0.3s) Iter 20, Step 330, episodic return is 9.20. {'loss': 0.0008, 'episode_len': 15.0}
# Environment is closed.
# Test passed!

# %% [markdown]
# ### Section 3.3: Train DQN agents in CartPole

# %%
# Run this cell without modification

pytorch_trainer, pytorch_stat = run(DQNTrainer, dict(
    max_iteration=2000,
    evaluate_interval=50, 
    learning_rate=0.01,
    clip_norm=10.0,
    memory_size=50000,
    learn_start=1000,
    eps=0.1,
    target_update_freq=1000,
    batch_size=32,
    env_name="CartPole-v0",
), reward_threshold=195.0)

reward, _ = pytorch_trainer.evaluate()
assert reward > 195.0, "Check your codes. " \
    "Your agent should achieve {} reward in 1000 iterations." \
    "But it achieve {} reward in evaluation.".format(195.0, reward)


pytorch_trainer.save("dqn_trainer_cartpole.pt")

# Should solve the task in 10 minutes
# Out:
# Setting up self.network with obs dim: 4 and action dim: 2
# Num inputs: 4, Num actions: 2
# Num inputs: 4, Num actions: 2
# (0.0s,+0.0s) Iter 0, Step 9, episodic return is 9.20. {'episode_len': 9.0}
# (0.1s,+0.1s) Iter 50, Step 451, episodic return is 9.20. {'episode_len': 10.0}
# Current memory contains 1000 transitions, start learning!
# 1002 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 1002
# (0.2s,+0.1s) Iter 100, Step 901, episodic return is 9.20. {'loss': 0.5548, 'episode_len': 11.0}
# (1.2s,+1.0s) Iter 150, Step 1344, episodic return is 9.20. {'loss': 0.1721, 'episode_len': 10.0}
# (2.2s,+1.0s) Iter 200, Step 1782, episodic return is 9.20. {'loss': 0.104, 'episode_len': 8.0}
# 1009 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 2011
# (3.2s,+1.0s) Iter 250, Step 2222, episodic return is 9.20. {'loss': 0.0133, 'episode_len': 10.0}
# (4.3s,+1.1s) Iter 300, Step 2667, episodic return is 9.40. {'loss': 0.0171, 'episode_len': 9.0}
# 1001 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 3012
# (5.6s,+1.3s) Iter 350, Step 3202, episodic return is 10.10. {'loss': 0.0154, 'episode_len': 11.0}
# 1005 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 4017
# (7.4s,+1.8s) Iter 400, Step 3944, episodic return is 32.10. {'loss': 0.0261, 'episode_len': 82.0}
# 1054 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 5071
# 1074 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 6145
# 1082 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 7227
# 1002 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 8229
# 1035 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 9264
# (19.5s,+12.1s) Iter 450, Step 9013, episodic return is 189.80. {'loss': 0.158, 'episode_len': 199.0}
# 1082 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 10346
# 1156 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 11502
# 1058 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 12560
# 1064 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 13624
# 1079 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 14703
# 1058 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 15761
# 1105 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 16866
# (39.1s,+19.6s) Iter 500, Step 16958, episodic return is 126.80. {'loss': 0.7463, 'episode_len': 141.0}
# 1039 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 17905
# 1095 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 19000
# 1098 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 20098
# 1004 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 21102
# 1148 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 22250
# 1102 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 23352
# (53.0s,+14.0s) Iter 550, Step 23004, episodic return is 18.40. {'loss': 2.7766, 'episode_len': 30.0}
# 1055 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 24407
# 1149 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 25556
# 1125 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 26681
# 1002 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 27683
# 1089 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 28772
# 1033 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 29805
# (66.7s,+13.7s) Iter 600, Step 29595, episodic return is 91.20. {'loss': 2.8025, 'episode_len': 199.0}
# 1198 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 31003
# 1002 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 32005
# 1028 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 33033
# 1066 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 34099
# 1076 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 35175
# 1024 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 36199
# (80.7s,+14.0s) Iter 650, Step 35943, episodic return is 20.30. {'loss': 3.0908, 'episode_len': 139.0}
# 1054 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 37253
# 1048 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 38301
# 1073 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 39374
# 1026 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 40400
# 1046 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 41446
# (92.9s,+12.2s) Iter 700, Step 41409, episodic return is 16.90. {'loss': 5.1551, 'episode_len': 148.0}
# 1034 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 42480
# 1003 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 43483
# 1021 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 44504
# 1002 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 45506
# (101.4s,+8.6s) Iter 750, Step 45076, episodic return is 22.20. {'loss': 10.804, 'episode_len': 61.0}
# 1008 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 46514
# 1055 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 47569
# 1030 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 48599
# (109.9s,+8.5s) Iter 800, Step 48767, episodic return is 24.20. {'loss': 9.5017, 'episode_len': 11.0}
# 1013 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 49612
# 1029 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 50641
# 1073 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 51714
# 1139 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 52853
# (119.8s,+9.9s) Iter 850, Step 52991, episodic return is 85.30. {'loss': 9.3079, 'episode_len': 161.0}
# 1189 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 54042
# 1047 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 55089
# 1058 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 56147
# 1034 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 57181
# (127.2s,+7.4s) Iter 900, Step 56331, episodic return is 90.30. {'loss': 9.0098, 'episode_len': 24.0}
# 1028 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 58209
# 1017 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 59226
# 1009 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 60235
# (135.2s,+8.0s) Iter 950, Step 60108, episodic return is 54.80. {'loss': 7.246, 'episode_len': 24.0}
# 1022 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 61257
# 1040 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 62297
# 1022 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 63319
# (141.9s,+6.7s) Iter 1000, Step 63250, episodic return is 17.40. {'loss': 20.0221, 'episode_len': 40.0}
# 1069 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 64388
# 1030 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 65418
# (145.8s,+4.0s) Iter 1050, Step 65105, episodic return is 14.70. {'loss': 16.7387, 'episode_len': 11.0}
# 1008 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 66426
# 1034 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 67460
# 1063 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 68523
# (150.8s,+5.0s) Iter 1100, Step 67422, episodic return is 13.10. {'loss': 14.6569, 'episode_len': 75.0}
# 1016 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 69539
# 1013 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 70552
# (155.8s,+5.0s) Iter 1150, Step 69640, episodic return is 95.60. {'loss': 20.7791, 'episode_len': 10.0}
# 1060 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 71612
# 1001 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 72613
# (160.8s,+5.0s) Iter 1200, Step 71829, episodic return is 71.50. {'loss': 16.7471, 'episode_len': 12.0}
# 1012 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 73625
# 1029 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 74654
# (166.2s,+5.3s) Iter 1250, Step 74176, episodic return is 43.60. {'loss': 26.1106, 'episode_len': 86.0}
# 1021 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 75675
# 1024 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 76699
# (170.7s,+4.5s) Iter 1300, Step 76146, episodic return is 16.20. {'loss': 33.0991, 'episode_len': 28.0}
# 1008 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 77707
# 1082 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 78789
# (175.8s,+5.1s) Iter 1350, Step 78391, episodic return is 60.10. {'loss': 33.4149, 'episode_len': 33.0}
# 1008 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 79797
# 1017 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 80814
# 1136 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 81950
# (181.5s,+5.7s) Iter 1400, Step 80794, episodic return is 200.00. {'loss': 23.9494, 'episode_len': 48.0}
# In 1400 iteration, episodic return 200.000 is greater than reward threshold 195.0. Congratulation! Now we exit the training process.
# Environment is closed.

# %%
# Run this cell without modification

# Render the learned behavior
eval_reward, eval_info = evaluate(
    policy=pytorch_trainer.policy, 
    num_episodes=1, 
    env_name=pytorch_trainer.env_name,
    render="rgb_array",  # Visualize the behavior here in the cell 
)

animate(eval_info["frames"])

print("DQN agent achieves {} return.".format(eval_reward))
# Out:
# DQN agent achieves 200.0 return.

# %% [markdown]
# ### Section 3.4: Train DQN agents in MetaDrive

# %%
# Run this cell without modification

def register_metadrive():
    from gym.envs.registration import register
    from gym import Wrapper
    try:
        from metadrive.envs import MetaDriveEnv
        from metadrive.utils.config import merge_config_with_unknown_keys
    except ImportError as e:
        print("Please install MetaDrive through: pip install git+https://github.com/decisionforce/metadrive")
        raise e

    env_names = []
    try:
        class MetaDriveEnvD(Wrapper):
            def __init__(self, config, *args, **kwargs):
                super().__init__(MetaDriveEnv(config))
                self.action_space = gym.spaces.Discrete(int(np.prod(self.env.action_space.nvec)))

        _make_env = lambda config=None: MetaDriveEnvD(config)
        
        env_name = "MetaDrive-Tut-Easy-v0"
        register(id=env_name, entry_point=_make_env, kwargs={"config": dict(
            map="S",
            start_seed=0,
            environment_num=1,
            horizon=200,
            discrete_action=True,
            discrete_steering_dim=3, 
            discrete_throttle_dim=3
        )})
        env_names.append(env_name)
        
        env_name = "MetaDrive-Tut-Hard-v0"
        register(id=env_name, entry_point=_make_env, kwargs={"config": dict(
            map="CCC",
            start_seed=0,
            environment_num=10,
            discrete_action=True,
            discrete_steering_dim=5, 
            discrete_throttle_dim=5
        )})
        env_names.append(env_name)
    except gym.error.Error as e:
        print("Information when registering MetaDrive: ", e)
    else:
        print("Successfully registered MetaDrive environments: ", env_names)

# %%
# Run this cell without modification

register_metadrive()
# Out:
# Information when registering MetaDrive:  Cannot re-register id: MetaDrive-Tut-Easy-v0

# %%
# Run this cell without modification

# Build the test trainer.
test_trainer = DQNTrainer(dict(env_name="MetaDrive-Tut-Easy-v0"))

# Test compute_values
for _ in range(10):
    fake_state = test_trainer.env.observation_space.sample()
    processed_state = test_trainer.process_state(fake_state)
    assert processed_state.shape == (test_trainer.obs_dim, ), processed_state.shape
    values = test_trainer.compute_values(processed_state)
    assert values.shape == (test_trainer.act_dim, ), values.shape

    test_trainer.train()

print("Now your codes should be bug-free.")
test_trainer.env.close()
del test_trainer
# Out:
# WARNING:root:BaseEngine is not launched, fail to sync seed to engine!
# Setting up self.network with obs dim: 259 and action dim: 9
# Num inputs: 259, Num actions: 9
# Num inputs: 259, Num actions: 9
# :task(warning): Creating implicit AsyncTaskChain default for AsyncTaskManager TaskManager
# Now your codes should be bug-free.

# %%
# Run this cell without modification

env_name = "MetaDrive-Tut-Easy-v0"

pytorch_trainer2, _ = run(DQNTrainer, dict(
    max_episode_length=200,
    max_iteration=5000,
    evaluate_interval=10,
    evaluate_num_episodes=10,
    learning_rate=0.0001,
    clip_norm=10.0,
    memory_size=1000000,
    learn_start=2000,
    eps=0.1,
    target_update_freq=5000,
    learn_freq=16,
    batch_size=256,
    env_name=env_name
), reward_threshold=120)


pytorch_trainer2.save("dqn_trainer_metadrive_easy.pt")
# Out:
# WARNING:root:BaseEngine is not launched, fail to sync seed to engine!
# Setting up self.network with obs dim: 259 and action dim: 9
# Num inputs: 259, Num actions: 9
# Num inputs: 259, Num actions: 9
# :task(warning): Creating implicit AsyncTaskChain default for AsyncTaskManager TaskManager
# (2.6s,+2.6s) Iter 0, Step 199, episodic return is -0.78. {'episode_len': 199.0}
# (5.3s,+2.7s) Iter 10, Step 2128, episodic return is -4.38. {'loss': 0.0028, 'episode_len': 138.0, 'success_rate': 0.0}
# (8.9s,+3.6s) Iter 20, Step 2817, episodic return is 0.01. {'loss': 0.1172, 'episode_len': 199.0}
# (13.6s,+4.7s) Iter 30, Step 4409, episodic return is 125.58. {'loss': 0.0723, 'episode_len': 48.0, 'success_rate': 0.0}
# In 30 iteration, episodic return 125.581 is greater than reward threshold 120. Congratulation! Now we exit the training process.
# Environment is closed.

# %%
# Run this cell without modification

# Render the learned behavior
# NOTE: The learned agent is marked by green color.
eval_reward, eval_info = evaluate(
    policy=pytorch_trainer2.policy, 
    num_episodes=1, 
    env_name=pytorch_trainer2.env_name,
    render="topdown",  # Visualize the behaviors in top-down view
    verbose=True
)

frames = [pygame.surfarray.array3d(f).swapaxes(0, 1) for f in eval_info["frames"]]

animate(frames)

print("DQN agent achieves {} return in MetaDrive easy environment.".format(eval_reward))
# Out:
# DQN agent achieves 125.58145966674864 return in MetaDrive easy environment.

# %% [markdown]
# ### Section 3.5: Train agent to solve harder driving task using DQN!
#
# We will train agent to solve a hard MetaDrive environment with multiple curved road segments. We will visualize the behavior of agent later.
#
# The training log of my experiment is left below for your information. As you can see the performance is not good in terms of the zero success rate.
#
# **GOAL: achieve episodic return > 50.**
#
#
# **BONUS!!** **can be earned if you can improve the training performance by adjusting hyper-parameters and optimizing code. Improvement means achieving > 0.0 success rate. However, I can't promise that it is feasible to use DQN algorithm to solve this task.** Please creates a independent markdown cell to highlight your improvement.

# %%
# Run this cell without modification
# (of course you can adjust hyper-parameters if you like)

# We might want to stop the training and restore later.
# Therefore, we don't use the `run` function but instead
# explicitly expose the trainer here.
# This can avoid the loss of trained agent if any unexpected error
# happens during training and thus you can stop at any time and then
# run next cell to see the visualization.
# This also allow us to save and restore the intermiedate agents if want.


metadrive_config = dict(
    max_episode_length=1000,
    max_iteration=5000,
    evaluate_interval=50,
    evaluate_num_episodes=5,
    learning_rate=0.0001,
    clip_norm=10.0,
    memory_size=1000000,
    learn_start=5000,
    eps=0.2,
    target_update_freq=5000,
    learn_freq=16,
    batch_size=256,
    env_name="MetaDrive-Tut-Hard-v0"
)

metadrive_reward_threshold = 1000

metadrive_trainer = DQNTrainer(metadrive_config)

# We might want to load trained trainer to pick up training:
if os.path.isfile("dqn_trainer_metadrive_hard.pt"):
    metadrive_trainer.load("dqn_trainer_metadrive_hard.pt")


metadrive_config = metadrive_trainer.config
start = now = time.time()
stats = []
total_steps = 0
try:
    for i in range(metadrive_config['max_iteration'] + 1):
        stat = metadrive_trainer.train()
        stat = stat or {}
        stats.append(stat)

        metadrive_trainer.save("dqn_trainer_metadrive_hard.pt")
        
        if "episode_len" in stat:
            total_steps += stat["episode_len"]
        if i % metadrive_config['evaluate_interval'] == 0 or \
                i == metadrive_config["max_iteration"]:
            reward, _ = metadrive_trainer.evaluate(
                metadrive_config.get("evaluate_num_episodes", 50), 
                max_episode_length=metadrive_config.get("max_episode_length", 1000)
            )
            print("({:.1f}s,+{:.1f}s) Iter {}, {}episodic return"
                  " is {:.2f}. {}".format(
                        time.time() - start, 
                        time.time() - now, 
                        i, 
                        "" if total_steps == 0 else "Step {}, ".format(total_steps),
                        reward,
                        {k: round(np.mean(v), 4) for k, v in stat.items() 
                        if not np.isnan(v) and k != "frames"
                        }
                              if stat else ""
                  ))
            now = time.time()
        if metadrive_reward_threshold is not None and reward > metadrive_reward_threshold:
            print("In {} iteration, episodic return {:.3f} is "
                  "greater than reward threshold {}. Congratulation! Now we "
                  "exit the training process.".format(
                i, reward, metadrive_reward_threshold))
            break
except Exception as e:
    print("Error happens during training: ")
    raise e
finally:
    if hasattr(metadrive_trainer.env, "close"):
        metadrive_trainer.env.close()
        print("Environment is closed.")
# Out:
# WARNING:root:BaseEngine is not launched, fail to sync seed to engine!
# Setting up self.network with obs dim: 259 and action dim: 25
# Num inputs: 259, Num actions: 25
# Num inputs: 259, Num actions: 25
# :task(warning): Creating implicit AsyncTaskChain default for AsyncTaskManager TaskManager
# (3.1s,+3.1s) Iter 0, Step 87, episodic return is 50.27. {'episode_len': 87.0, 'success_rate': 0.0}
# 5090 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 5090
# (26.8s,+23.7s) Iter 50, Step 6178, episodic return is 0.14. {'loss': 0.3877, 'episode_len': 84.0, 'success_rate': 0.0}
# (41.4s,+14.5s) Iter 100, Step 9817, episodic return is 2.35. {'loss': 0.1475, 'episode_len': 43.0, 'success_rate': 0.0}
# 5034 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 10124
# (60.0s,+18.6s) Iter 150, Step 14290, episodic return is 5.61. {'loss': 0.259, 'episode_len': 75.0, 'success_rate': 0.0}
# 5080 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 15204
# 5070 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 20274
# (83.2s,+23.2s) Iter 200, Step 20336, episodic return is 35.50. {'loss': 0.2454, 'episode_len': 70.0, 'success_rate': 0.0}
# 5193 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 25467
# (120.3s,+37.1s) Iter 250, Step 29800, episodic return is 16.25. {'loss': 0.1942, 'episode_len': 44.0, 'success_rate': 0.0}
# 5084 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 30551
# 5019 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 35570
# (146.6s,+26.2s) Iter 300, Step 35633, episodic return is 70.97. {'loss': 0.2261, 'episode_len': 69.0, 'success_rate': 0.0}
# 5033 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 40603
# (172.7s,+26.1s) Iter 350, Step 41458, episodic return is 38.27. {'loss': 0.3206, 'episode_len': 69.0, 'success_rate': 0.0}
# 5104 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 45707
# (213.4s,+40.8s) Iter 400, Step 49858, episodic return is 76.78. {'loss': 0.2283, 'episode_len': 92.0, 'success_rate': 0.0}
# 5089 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 50796
# 5047 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 55843
# (243.5s,+30.1s) Iter 450, Step 56556, episodic return is 14.67. {'loss': 0.4525, 'episode_len': 71.0, 'success_rate': 0.0}
# 5132 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 60975
# (269.0s,+25.5s) Iter 500, Step 61866, episodic return is 64.73. {'loss': 0.5633, 'episode_len': 123.0, 'success_rate': 0.0}
# 5177 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 66152
# (291.9s,+22.9s) Iter 550, Step 66836, episodic return is 61.95. {'loss': 0.6179, 'episode_len': 104.0, 'success_rate': 0.0}
# 5012 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 71164
# (314.9s,+23.0s) Iter 600, Step 71878, episodic return is 61.49. {'loss': 0.425, 'episode_len': 86.0, 'success_rate': 0.0}
# 5068 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 76232
# (341.1s,+26.2s) Iter 650, Step 77599, episodic return is 57.71. {'loss': 0.4647, 'episode_len': 105.0, 'success_rate': 0.0}
# 5044 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 81276
# (359.7s,+18.6s) Iter 700, Step 81572, episodic return is 56.46. {'loss': 0.7934, 'episode_len': 87.0, 'success_rate': 0.0}
# 5008 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 86284
# (381.5s,+21.8s) Iter 750, Step 86380, episodic return is 57.94. {'loss': 1.294, 'episode_len': 99.0, 'success_rate': 0.0}
# 5093 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 91377
# (403.9s,+22.3s) Iter 800, Step 91196, episodic return is 59.00. {'loss': 1.0861, 'episode_len': 90.0, 'success_rate': 1.0}
# 5063 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 96440
# (423.7s,+19.8s) Iter 850, Step 95589, episodic return is 61.62. {'loss': 0.9027, 'episode_len': 69.0, 'success_rate': 1.0}
# (446.0s,+22.3s) Iter 900, Step 100470, episodic return is 55.70. {'loss': 0.8871, 'episode_len': 223.0, 'success_rate': 0.0}
# 5024 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 101464
# (466.5s,+20.5s) Iter 950, Step 104832, episodic return is 57.60. {'loss': 0.5863, 'episode_len': 30.0, 'success_rate': 0.0}
# 5016 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 106480
# (493.0s,+26.5s) Iter 1000, Step 109457, episodic return is 57.38. {'loss': 0.8623, 'episode_len': 97.0, 'success_rate': 0.0}
# 5006 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 111486
# (518.7s,+25.8s) Iter 1050, Step 114200, episodic return is 58.66. {'loss': 1.0352, 'episode_len': 86.0, 'success_rate': 0.0}
# 5041 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 116527
# (543.1s,+24.3s) Iter 1100, Step 119509, episodic return is 29.85. {'loss': 1.4307, 'episode_len': 118.0, 'success_rate': 0.0}
# 5012 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 121539
# (565.3s,+22.3s) Iter 1150, Step 124060, episodic return is 40.64. {'loss': 1.41, 'episode_len': 73.0, 'success_rate': 0.0}
# 5058 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 126597
# (590.5s,+25.2s) Iter 1200, Step 129032, episodic return is 56.61. {'loss': 1.446, 'episode_len': 72.0, 'success_rate': 0.0}
# 5077 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 131674
# (614.2s,+23.7s) Iter 1250, Step 133947, episodic return is 42.52. {'loss': 0.7426, 'episode_len': 60.0, 'success_rate': 0.0}
# 5002 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 136676
# (638.1s,+23.9s) Iter 1300, Step 139136, episodic return is 56.44. {'loss': 1.9972, 'episode_len': 168.0, 'success_rate': 0.0}
# 5007 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 141683
# (664.3s,+26.2s) Iter 1350, Step 144328, episodic return is 56.44. {'loss': 1.5037, 'episode_len': 85.0, 'success_rate': 0.0}
# 5109 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 146792
# (688.5s,+24.2s) Iter 1400, Step 149294, episodic return is 60.37. {'loss': 1.4758, 'episode_len': 102.0, 'success_rate': 0.0}
# 5046 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 151838
# (713.9s,+25.4s) Iter 1450, Step 154197, episodic return is 57.33. {'loss': 3.7143, 'episode_len': 92.0, 'success_rate': 0.0}
# 5066 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 156904
# (735.5s,+21.6s) Iter 1500, Step 158401, episodic return is 57.61. {'loss': 3.2498, 'episode_len': 118.0, 'success_rate': 0.0}
# 5023 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 161927
# (758.0s,+22.5s) Iter 1550, Step 162939, episodic return is 33.11. {'loss': 2.8116, 'episode_len': 119.0, 'success_rate': 0.0}
# 5049 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 166976
# (783.6s,+25.6s) Iter 1600, Step 167975, episodic return is 45.02. {'loss': 4.6825, 'episode_len': 67.0, 'success_rate': 0.0}
# 5044 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 172020
# (808.3s,+24.7s) Iter 1650, Step 172898, episodic return is 54.14. {'loss': 3.7888, 'episode_len': 52.0, 'success_rate': 0.0}
# 5084 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 177104
# (831.8s,+23.5s) Iter 1700, Step 177827, episodic return is 55.31. {'loss': 3.304, 'episode_len': 119.0, 'success_rate': 0.0}
# 5127 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 182231
# (858.4s,+26.6s) Iter 1750, Step 183235, episodic return is 64.25. {'loss': 4.5943, 'episode_len': 121.0, 'success_rate': 0.0}
# 5032 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 187263
# (884.5s,+26.0s) Iter 1800, Step 188377, episodic return is 37.96. {'loss': 4.574, 'episode_len': 65.0, 'success_rate': 0.0}
# 5008 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 192271
# (909.7s,+25.2s) Iter 1850, Step 193720, episodic return is 58.34. {'loss': 4.5355, 'episode_len': 78.0, 'success_rate': 0.0}
# 5172 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 197443
# (936.9s,+27.2s) Iter 1900, Step 199004, episodic return is 73.59. {'loss': 4.5851, 'episode_len': 83.0, 'success_rate': 0.0}
# 5041 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 202484
# (958.6s,+21.7s) Iter 1950, Step 203568, episodic return is 45.60. {'loss': 3.8191, 'episode_len': 126.0, 'success_rate': 0.0}
# 5082 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 207566
# (986.4s,+27.9s) Iter 2000, Step 209465, episodic return is 55.94. {'loss': 4.2282, 'episode_len': 134.0, 'success_rate': 0.0}
# 5006 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 212572
# (1011.6s,+25.2s) Iter 2050, Step 214595, episodic return is 61.68. {'loss': 4.3469, 'episode_len': 81.0, 'success_rate': 0.0}
# 5080 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 217652
# (1035.6s,+24.1s) Iter 2100, Step 219578, episodic return is 55.25. {'loss': 4.878, 'episode_len': 95.0, 'success_rate': 0.0}
# 5083 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 222735
# 5025 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 227760
# (1065.4s,+29.8s) Iter 2150, Step 225823, episodic return is 68.99. {'loss': 7.2707, 'episode_len': 213.0, 'success_rate': 0.0}
# 5032 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 232792
# (1093.6s,+28.2s) Iter 2200, Step 232018, episodic return is 59.83. {'loss': 7.5175, 'episode_len': 84.0, 'success_rate': 0.0}
# 5064 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 237856
# (1126.0s,+32.4s) Iter 2250, Step 238822, episodic return is 43.73. {'loss': 4.5576, 'episode_len': 305.0, 'success_rate': 0.0}
# 5030 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 242886
# 5126 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 248012
# (1160.6s,+34.6s) Iter 2300, Step 245859, episodic return is 90.61. {'loss': 5.4364, 'episode_len': 80.0, 'success_rate': 0.0}
# 5136 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 253148
# (1192.0s,+31.4s) Iter 2350, Step 252382, episodic return is 52.39. {'loss': 3.7316, 'episode_len': 125.0, 'success_rate': 0.0}
# 5454 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 258602
# (1228.3s,+36.3s) Iter 2400, Step 259860, episodic return is 64.08. {'loss': 9.4388, 'episode_len': 96.0, 'success_rate': 0.0}
# 5245 steps has passed since last update. Now update the parameter of the behavior policy. Current step: 263847
# Environment is closed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/18/mc_7692d7c9665mhcdrpp2v00000gn/T/ipykernel_37004/3294512945.py in <module>
#      42 try:
#      43     for i in range(metadrive_config['max_iteration'] + 1):
# ---> 44         stat = metadrive_trainer.train()
#      45         stat = stat or {}
#      46         stats.append(stat)
#
# /var/folders/18/mc_7692d7c9665mhcdrpp2v00000gn/T/ipykernel_37004/2816620204.py in train(self)
#     129
#     130     def train(self):
# --> 131         s = self.env.reset()
#     132         processed_s = self.process_state(s)
#     133         act = self.compute_action(processed_s)
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/gym/core.py in reset(self, **kwargs)
#     249
#     250     def reset(self, **kwargs):
# --> 251         return self.env.reset(**kwargs)
#     252
#     253     def render(self, mode="human", **kwargs):
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/metadrive/envs/base_env.py in reset(self, force_seed)
#     338                 "singleton of MetaDrive and restart your program."
#     339             )
# --> 340         self.engine.reset()
#     341         if self._top_down_renderer is not None:
#     342             self._top_down_renderer.reset(self.current_map)
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/metadrive/engine/base_engine.py in reset(self)
#     193         self._object_clean_check()
#     194         for manager in self.managers.values():
# --> 195             manager.reset()
#     196         for manager in self.managers.values():
#     197             manager.after_reset()
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/metadrive/manager/traffic_manager.py in reset(self)
#      64             self._create_respawn_vehicles(map, traffic_density)
#      65         elif self.mode == TrafficMode.Trigger or self.mode == TrafficMode.Hybrid:
# ---> 66             self._create_vehicles_once(map, traffic_density)
#      67         else:
#      68             raise ValueError("No such mode named {}".format(self.mode))
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/metadrive/manager/traffic_manager.py in _create_vehicles_once(self, map, traffic_density)
#     264                 vehicle_type = self.random_vehicle_type()
#     265                 v_config.update(self.engine.global_config["traffic_vehicle_config"])
# --> 266                 random_v = self.spawn_object(vehicle_type, vehicle_config=v_config)
#     267                 self.add_policy(random_v.id, IDMPolicy(random_v, self.generate_seed()))
#     268                 vehicles_on_block.append(random_v)
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/metadrive/manager/base_manager.py in spawn_object(self, object_class, **kwargs)
#      61         Spawn one objects
#      62         """
# ---> 63         object = self.engine.spawn_object(object_class, **kwargs)
#      64         self.spawned_objects[object.id] = object
#      65         return object
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/metadrive/engine/base_engine.py in spawn_object(self, object_class, pbr_model, force_spawn, auto_fill_random_seed, **kwargs)
#     107         else:
#     108             obj = self._dying_objects[object_class.__name__].pop()
# --> 109             obj.reset(**kwargs)
#     110         if self.global_config["record_episode"] and not self.replay_episode:
#     111             self.record_manager.add_spawn_info(object_class, kwargs, obj.name)
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/metadrive/component/vehicle/base_vehicle.py in reset(self, random_seed, vehicle_config, position, heading, *args, **kwargs)
#     318         self.set_position(position, self.HEIGHT / 2 + 1)
#     319         self.origin.setQuat(LQuaternionf(math.cos(heading / 2), 0, 0, math.sin(heading / 2)))
# --> 320         self.update_map_info(map)
#     321         self.body.clearForces()
#     322         self.body.setLinearVelocity(Vec3(0, 0, 0))
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/metadrive/component/vehicle/base_vehicle.py in update_map_info(self, map)
#     611             current_lane=lane,
#     612             destination=dest if dest is not None else None,
# --> 613             random_seed=self.engine.global_random_seed
#     614         )
#     615         assert lane is not None, "spawn place is not on road!"
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/metadrive/component/vehicle_navigation_module/node_network_navigation.py in reset(self, map, current_lane, destination, random_seed)
#      39         super(NodeNetworkNavigation, self).reset(map, current_lane)
#      40         assert self.map.road_network_type == NodeRoadNetwork, "This Navigation module only support NodeRoadNetwork type"
# ---> 41         destination = self.auto_assign_task(map, current_lane.index, destination, random_seed)
#      42         self.set_route(current_lane.index, destination)
#      43
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/metadrive/component/vehicle_navigation_module/node_network_navigation.py in auto_assign_task(map, current_lane_index, final_road_node, random_seed)
#      53             block = map.blocks[0] if current_road_negative else map.blocks[-1]
#      54             sockets = block.get_socket_list()
# ---> 55             socket = get_np_random(random_seed).choice(sockets)
#      56             while True:
#      57                 if not socket.is_socket_node(start_road_node) or len(sockets) == 1:
#
# KeyboardInterrupt:

# %%
# Run this cell without modification

# Render the learned behavior
# NOTE: The learned agent is marked by green color.
eval_reward, eval_info = evaluate(
    policy=metadrive_trainer.policy, 
    num_episodes=1, 
    env_name=metadrive_trainer.env_name,
    render="topdown",  # Visualize the behaviors in top-down view
    verbose=True
)

frames = [pygame.surfarray.array3d(f).swapaxes(0, 1) for f in eval_info["frames"]]

animate(frames)

print("DQN agent achieves {} return in MetaDrive hard environment.".format(eval_reward))
# Out:
# DQN agent achieves 74.52874452759256 return in MetaDrive hard environment.

# %% [markdown]
# ## Section 4: Policy gradient methods - REINFORCE
#
# (30 / 100 points)
#
# Unlike supervised learning, in RL the optimization objective return is not differentiable w.r.t. the neural network parameters. This can be workaround via ***Policy Gradient***. It can be proved that policy gradient is an unbiased estimator of the gradient of the objective.
#
# Concretely, let's consider such optimization objective:
#
# $$Q = \mathbb E_{\text{possible trajectories}} \sum_t r(a_t, s_t) = \sum_{s_0, a_0,..} p(s_0, a_0, ..., s_t, a_t) r(s_0, a_0, ..., s_t, a_t) = \sum_{\tau} p(\tau)r(\tau)$$
#
# wherein $\sum_t r(a_t, s_t) = r(\tau)$ is the return of trajectory $\tau = (s_0, a_0, ...)$. We remove the discount factor for simplicity.
# Since we want to maximize Q, we can simply compute the gradient of Q w.r.t. parameter $\theta$ (which is implictly included in $p(\tau)$):
#
# $$\nabla_\theta Q = \nabla_\theta \sum_{\tau} p(\tau)r(\tau) = \sum_{\tau} r(\tau) \nabla_\theta p(\tau)$$
#
# Apply a famous trick: $\nabla_\theta p(\tau) = p(\tau)\cfrac{\nabla_\theta p(\tau)}{p(\tau)} = p(\tau)\nabla_\theta \log p(\tau)$.
#
# Introducing a log term can change the product of probabilities to sum of log probabilities. Now we can expand the log of product above to sum of log:
#
# $$p_\theta(\tau) = p(s_0, a_0, ...) = p(s_0) \prod_t \pi_\theta (a_t|s_t) p(s_{t+1}|s_t, a_t)$$
#
# $$\log p_\theta (\tau) = \log p(s_0) + \sum_t \log \pi_\theta(a_t|s_t) + \sum_t \log p(s_{t+1}|s_t, a_t)$$
#
# You can find that the first and third term are not correlated to the parameter of policy $\pi_\theta(\cdot)$. So when we moving back to $\nabla_\theta Q$, we find
#
# $$\nabla_\theta Q =
# \sum_{\tau} r(\tau) \nabla_\theta p(\tau) =
# \sum_{\tau} r(\tau) p(\tau)\nabla_\theta \log p(\tau) =
# \sum p_\theta(\tau) ( \sum_t  \nabla_\theta \log \pi_\theta(a_t|s_t) ) r(\tau) d\tau$$
#
# When we sample sufficient amount of data from the environment, the above equation can be estimated via:
#
# $$\nabla_\theta Q =\cfrac{1}{N}\sum_{i=1}^N [( \sum_t  \nabla_\theta \log \pi_\theta(a_{i,t}|s_{i,t}) (\sum_{t'=t} \gamma^{t'-t} r(s_{i,t'}, a_{i,t'}) )]$$
#
# This algorithm is called REINFORCE algorithm, which is a Monte Carlo Policy Gradient algorithm with long history. In this section, we will implement the it using pytorch.

# %% [markdown]
# The policy network is composed by two parts:
#
# 1. A basic neural network serves as the function approximator. It output raw values parameterizing the action distribution given current observation. We will reuse PytorchModel here.
# 2. A distribution layer builds upon the neural network to wrap the raw logits output from neural network to a distribution and provides API for sampling action and computing log probability.

# %% [markdown]
# ### Section 4.1: Build REINFORCE

# %%
# Run this cell without modification

class PGNetwork(nn.Module):
    def __init__(self, obs_dim, act_dim, hidden_units=128):
        super(PGNetwork, self).__init__()
        self.network = PytorchModel(obs_dim, act_dim, hidden_units)

    def forward(self, obs):
        logit = self.network(obs)
        
        # [TODO] Create an object of the class "torch.distributions.Categorical" 
        #  with logit. Hint: don't mess up `logits`
        # Then sample an action from it.
        action = torch.distributions.Categorical(logits=logit).sample()
        #sample from a distribution
        
        return action

    def log_prob(self, obs, act):
        logits = self.network(obs)
        
        # [TODO] Create an object of the class "torch.distributions.Categorical" 
        # Then get the log probability of the action `act` in this distribution.
        dist = torch.distributions.Categorical(logits=logits)      
        log_prob = dist.log_prob(act)
        return log_prob

# Note that we do not implement GaussianPolicy here. So we can't
# apply our algorithm to the environment with continous action.

# %%
# Solve the TODOs and remove `pass`

PG_DEFAULT_CONFIG = merge_config(dict(
    normalize_advantage=True,
    
    clip_norm=10.0,
    clip_gradient=True,
    
    hidden_units=100,
    
        
    max_iteration=1000,
    
    train_batch_size=1000,
    gamma=0.99,
    learning_rate=0.01,
    
    
    env_name="CartPole-v0",
    
), DEFAULT_CONFIG)



class PGTrainer(AbstractTrainer):
    def __init__(self, config=None):
        config = merge_config(config, PG_DEFAULT_CONFIG)
        super().__init__(config)
        
        self.iteration = 0
        self.start_time = time.time()
        self.iteration_time = self.start_time
        self.total_timesteps = 0
        self.total_episodes = 0

        # build the model
        self.initialize_parameters()

    def initialize_parameters(self):
        """Build the policy network and related optimizer"""
        # Detect whether you have GPU or not. Remember to call X.to(self.device)
        # if necessary.
        self.device = torch.device(
            "cuda" if torch.cuda.is_available() else "cpu"
        )
        
        # Build the policy network
        self.network = PGNetwork(
            self.obs_dim, self.act_dim,
            hidden_units=self.config["hidden_units"]
        ).to(self.device)
        
        # Build the Adam optimizer.
        self.optimizer = torch.optim.Adam(
            self.network.parameters(),
            lr=self.config["learning_rate"]
        )

    def to_tensor(self, array):
        """Transform a numpy array to a pytorch tensor"""
        return torch.from_numpy(array).type(torch.float32).to(self.device)

    def to_array(self, tensor):
        """Transform a pytorch tensor to a numpy array"""
        ret = tensor.cpu().detach().numpy()
        if ret.size == 1:
            ret = ret.item()
        return ret
    
    def save(self, loc="model.pt"):
        torch.save(self.network.state_dict(), loc)
        
    def load(self, loc="model.pt"):
        self.network.load_state_dict(torch.load(loc))

    def compute_action(self, observation, eps=None):
        """Compute the action for single observation. eps is useless here."""
        assert observation.ndim == 1
        
        # [TODO] Sample an action from action distribution given by the policy
        # Hint: The input of policy network is a batch of data, so you need to
        #  expand the first dimension of observation before feeding it to policy network.
        
        #action = self.network.forward(self.to_tensor(observation).expand(self.act_dim)).item()
        action = self.network.forward(torch.unsqueeze(self.to_tensor(observation),dim=0))
        action = self.to_array(action)
        return action

    def compute_log_probs(self, observation, action):
        """Compute the log probabilities of a batch of state-action pair"""
        # [TODO] Using the function of policy network to get log probs.
        # Hint: Remember to transform the data into tensor before feeding it.
        observation= self.to_tensor(observation)
        action= self.to_tensor(action)
        log_probs= self.network.log_prob(observation,action)

        return log_probs

    def process_samples(self, samples):
        """Process samples and add advantages in it"""
        values = []
        for reward_list in samples["reward"]:
            # reward_list contains rewards in one episode
            returns = np.zeros_like(reward_list, dtype=np.float32)
            Q = 0
            
            # [TODO] Scan the episode in a reverse order and compute the
            # discounted return at each time step. Fill the array `returns`
            for idx, r in enumerate(reward_list[::-1]):
                Q = r + (self.config["gamma"] * Q)
                returns[len(reward_list)-idx-1] = Q          
            values.append(returns)

        # We call the values advantage here.
        advantages = np.concatenate(values)

        if self.config["normalize_advantage"]:
            # [TODO] normalize the advantage so that it's mean is
            # almost 0 and the its standard deviation is almost 1.
            adv_std = advantages.std()
            advantages -= advantages.mean()
            advantages /= adv_std
        
        samples["advantages"] = advantages
        return samples, {}

    def update_network(self, processed_samples):
        """Update the policy network"""
        advantages = self.to_tensor(processed_samples["advantages"])
        flat_obs = np.concatenate(processed_samples["obs"])
        flat_act = np.concatenate(processed_samples["act"])

        self.network.train()
        self.optimizer.zero_grad()

        log_probs = self.compute_log_probs(flat_obs, flat_act)

        assert log_probs.shape == advantages.shape, "log_probs shape {} is not " \
            "compatible with advantages {}".format(log_probs.shape, advantages.shape)
        
        # [TODO] Compute the loss using log probabilities and advantages.
        policy_loss = []
        for log_prob, R in zip(log_probs,advantages):
            policy_loss.append(-log_prob*R)
        loss = torch.stack(policy_loss).sum()
        
        loss.backward()
        
        # Clip the gradient
        torch.nn.utils.clip_grad_norm_(
            self.network.parameters(), self.config["clip_gradient"]
        )

        self.optimizer.step()
        self.network.eval()
        
        update_info = {
            "policy_loss": loss.item(),
            "mean_log_prob": torch.mean(log_probs).item(),
            "mean_advantage": torch.mean(advantages).item()
        }
        return update_info
    
    # ===== Training-related functions =====
    def collect_samples(self):
        """Here we define the pipeline to collect sample even though
        any specify functions are not implemented yet.
        """
        iter_timesteps = 0
        iter_episodes = 0
        episode_lens = []
        episode_rewards = []
        episode_obs_list = []
        episode_act_list = []
        episode_reward_list = []
        success_list = []
        while iter_timesteps <= self.config["train_batch_size"]:
            obs_list, act_list, reward_list = [], [], []
            obs = self.env.reset()
            steps = 0
            episode_reward = 0
            while True:
                act = self.compute_action(obs)
                
                # print("ACT: ", act, type(act))
                
                next_obs, reward, done, step_info = self.env.step(act)

                obs_list.append(obs)
                act_list.append(act)
                reward_list.append(reward)

                obs = next_obs.copy()
                steps += 1
                episode_reward += reward
                if done or steps > self.config["max_episode_length"]:
                    if "arrive_dest" in step_info:
                        success_list.append(step_info["arrive_dest"])
                    break
            iter_timesteps += steps
            iter_episodes += 1
            episode_rewards.append(episode_reward)
            episode_lens.append(steps)
            episode_obs_list.append(np.array(obs_list, dtype=np.float32))
            episode_act_list.append(np.array(act_list, dtype=np.float32))
            episode_reward_list.append(np.array(reward_list, dtype=np.float32))
        
        # [TODO] Uncomment everything below and understand the data structure:
        # The return `samples` is a dict that contains several fields.
        # Each field (key-value pair) contains a list.
        # Each element in list is a list represent the data in one trajectory (episode).
        # Each episode list contains the data of that field of all time steps in that episode.
        # The return `sample_info` is a dict contains logging item name and its value.
        
        samples = {
            "obs": episode_obs_list,
            "act": episode_act_list,
            "reward": episode_reward_list
        }
        
        sample_info = {
            "iter_timesteps": iter_timesteps,
            "iter_episodes": iter_episodes,
            "performance": np.mean(episode_rewards),  # help drawing figures
            "ep_len": float(np.mean(episode_lens)),
            "ep_ret": float(np.mean(episode_rewards)),
            "episode_len": sum(episode_lens),
            "success_rate": np.mean(success_list)
        }
        return samples, sample_info
    
#     def process_samples(self, samples):
#         """Process samples and add advantages in it"""
#         values = []
#         for reward_list in samples["reward"]:
#             # reward_list contains rewards in one episode
#             returns = np.zeros_like(reward_list, dtype=np.float32)
#             Q = 0
            
#             for r in reward_list[::-1]:
#                 Q = r + self.gamma * Q
#                 returns.insert(0, r)                            
#             values.append(returns)

#         # We call the values advantage here.
#         advantages = np.concatenate(values)

#         if self.config["normalize_advantage"]:
#             # [TODO] normalize the advantage so that it's mean is
#             # almost 0 and the its standard deviation is almost 1.
#             pass
        
#         samples["advantages"] = advantages
#         return samples, {}
        
    # ===== Training iteration =====
    def train(self):
        """Here we defined the training pipeline using the abstract
        functions."""
        info = dict(iteration=self.iteration)

        # [TODO] Uncomment the following block and go through the learning 
        # pipeline.
        
        # Collect samples
        samples, sample_info = self.collect_samples()
        info.update(sample_info)

        # Process samples
        processed_samples, processed_info = self.process_samples(samples)
        info.update(processed_info)

        # Update the model
        update_info = self.update_network(processed_samples)
        info.update(update_info)
        

        now = time.time()
        self.iteration += 1
        self.total_timesteps += info.pop("iter_timesteps")
        self.total_episodes += info.pop("iter_episodes")
        
        # info["iter_time"] = now - self.iteration_time
        # info["total_time"] = now - self.start_time
        info["total_episodes"] = self.total_episodes
        info["total_timesteps"] = self.total_timesteps
        self.iteration_time = now
        
        # print("INFO: ", info)
        
        return info

# %% [markdown]
# ### Section 4.2: Test REINFORCE

# %%
# Run this cell without modification

# Test advantage computing
test_trainer = PGTrainer({"normalize_advantage": False})
test_trainer.train()
fake_sample = {"reward": [[2, 2, 2, 2, 2]]}
np.testing.assert_almost_equal(
    test_trainer.process_samples(fake_sample)[0]["reward"][0],
    fake_sample["reward"][0]
)
np.testing.assert_almost_equal(
    test_trainer.process_samples(fake_sample)[0]["advantages"],
    np.array([9.80199, 7.880798, 5.9402, 3.98, 2.], dtype=np.float32)
)

# Test advantage normalization
test_trainer = PGTrainer(
    {"normalize_advantage": True, "env_name": "LunarLander-v2"})
test_adv = test_trainer.process_samples(fake_sample)[0]["advantages"]
np.testing.assert_almost_equal(test_adv.mean(), 0.0)
np.testing.assert_almost_equal(test_adv.std(), 1.0)

# Test the shape of functions' returns
fake_observation = np.array([
    test_trainer.env.observation_space.sample() for i in range(10)
])
fake_action = np.array([
    test_trainer.env.action_space.sample() for i in range(10)
])
assert test_trainer.to_tensor(fake_observation).shape == torch.Size([10, 8])
assert np.array(test_trainer.compute_action(fake_observation[0])).shape == ()
assert test_trainer.compute_log_probs(fake_observation, fake_action).shape == \
       torch.Size([10])

print("Test Passed!")
# Out:
# Num inputs: 4, Num actions: 2
# Num inputs: 8, Num actions: 4
# Test Passed!

# %% [markdown]
# ### Section 4.3: Train REINFORCE in CartPole and see the impact of advantage normalization

# %%
# Run this cell without modification

pg_trainer_no_na, pg_result_no_na = run(PGTrainer, dict(
    learning_rate=0.01,
    max_episode_length=200,
    train_batch_size=200,
    env_name="CartPole-v0",
    normalize_advantage=False,  # <<== Here!
    
    evaluate_interval=10,
    evaluate_num_episodes=10,
), 195.0)
# Out:
# Num inputs: 4, Num actions: 2
# (0.2s,+0.2s) Iter 0, Step 212, episodic return is 26.00. {'iteration': 0.0, 'performance': 21.2, 'ep_len': 21.2, 'ep_ret': 21.2, 'episode_len': 212.0, 'policy_loss': 1816.4604, 'mean_log_prob': -0.6945, 'mean_advantage': 12.319, 'total_episodes': 10.0, 'total_timesteps': 212.0}
# (1.1s,+0.9s) Iter 10, Step 2605, episodic return is 93.40. {'iteration': 10.0, 'performance': 72.0, 'ep_len': 72.0, 'ep_ret': 72.0, 'episode_len': 216.0, 'policy_loss': 3819.126, 'mean_log_prob': -0.5217, 'mean_advantage': 33.1772, 'total_episodes': 60.0, 'total_timesteps': 2605.0}
# (2.1s,+1.1s) Iter 20, Step 5107, episodic return is 148.60. {'iteration': 20.0, 'performance': 96.0, 'ep_len': 96.0, 'ep_ret': 96.0, 'episode_len': 288.0, 'policy_loss': 5056.0332, 'mean_log_prob': -0.4646, 'mean_advantage': 36.8685, 'total_episodes': 88.0, 'total_timesteps': 5107.0}
# (3.0s,+0.9s) Iter 30, Step 7936, episodic return is 39.90. {'iteration': 30.0, 'performance': 52.2, 'ep_len': 52.2, 'ep_ret': 52.2, 'episode_len': 261.0, 'policy_loss': 2316.2461, 'mean_log_prob': -0.3667, 'mean_advantage': 23.4809, 'total_episodes': 117.0, 'total_timesteps': 7936.0}
# (4.4s,+1.4s) Iter 40, Step 11007, episodic return is 200.00. {'iteration': 40.0, 'performance': 200.0, 'ep_len': 200.0, 'ep_ret': 200.0, 'episode_len': 400.0, 'policy_loss': 9809.1094, 'mean_log_prob': -0.4211, 'mean_advantage': 57.132, 'total_episodes': 142.0, 'total_timesteps': 11007.0}
# In 40 iteration, episodic return 200.000 is greater than reward threshold 195.0. Congratulation! Now we exit the training process.
# Environment is closed.

# %%
# Run this cell without modification

pg_trainer_na, pg_result_na = run(PGTrainer, dict(
    learning_rate=0.01,
    max_episode_length=200,
    train_batch_size=200,
    env_name="CartPole-v0",
    normalize_advantage=True,  # <<== Here!
    
    evaluate_interval=10,
    evaluate_num_episodes=10,
), 195.0)
# Out:
# Num inputs: 4, Num actions: 2
# (0.2s,+0.2s) Iter 0, Step 225, episodic return is 28.90. {'iteration': 0.0, 'performance': 20.4545, 'ep_len': 20.4545, 'ep_ret': 20.4545, 'episode_len': 225.0, 'policy_loss': 0.6346, 'mean_log_prob': -0.6948, 'mean_advantage': 0.0, 'total_episodes': 11.0, 'total_timesteps': 225.0}
# (1.1s,+0.9s) Iter 10, Step 2525, episodic return is 92.00. {'iteration': 10.0, 'performance': 69.0, 'ep_len': 69.0, 'ep_ret': 69.0, 'episode_len': 207.0, 'policy_loss': -8.6847, 'mean_log_prob': -0.5549, 'mean_advantage': -0.0, 'total_episodes': 63.0, 'total_timesteps': 2525.0}
# (2.3s,+1.2s) Iter 20, Step 5296, episodic return is 191.00. {'iteration': 20.0, 'performance': 110.5, 'ep_len': 110.5, 'ep_ret': 110.5, 'episode_len': 221.0, 'policy_loss': -3.4922, 'mean_log_prob': -0.5924, 'mean_advantage': -0.0, 'total_episodes': 87.0, 'total_timesteps': 5296.0}
# (3.3s,+1.0s) Iter 30, Step 8278, episodic return is 75.10. {'iteration': 30.0, 'performance': 117.3333, 'ep_len': 117.3333, 'ep_ret': 117.3333, 'episode_len': 352.0, 'policy_loss': -1.2689, 'mean_log_prob': -0.5602, 'mean_advantage': -0.0, 'total_episodes': 109.0, 'total_timesteps': 8278.0}
# (4.7s,+1.4s) Iter 40, Step 11496, episodic return is 186.80. {'iteration': 40.0, 'performance': 200.0, 'ep_len': 200.0, 'ep_ret': 200.0, 'episode_len': 400.0, 'policy_loss': -1.163, 'mean_log_prob': -0.5727, 'mean_advantage': 0.0, 'total_episodes': 133.0, 'total_timesteps': 11496.0}
# (5.9s,+1.3s) Iter 50, Step 15022, episodic return is 110.20. {'iteration': 50.0, 'performance': 74.0, 'ep_len': 74.0, 'ep_ret': 74.0, 'episode_len': 296.0, 'policy_loss': -20.1557, 'mean_log_prob': -0.5423, 'mean_advantage': 0.0, 'total_episodes': 156.0, 'total_timesteps': 15022.0}
# (6.7s,+0.8s) Iter 60, Step 17393, episodic return is 67.30. {'iteration': 60.0, 'performance': 72.6667, 'ep_len': 72.6667, 'ep_ret': 72.6667, 'episode_len': 218.0, 'policy_loss': -2.2429, 'mean_log_prob': -0.4755, 'mean_advantage': -0.0, 'total_episodes': 178.0, 'total_timesteps': 17393.0}
# (8.0s,+1.3s) Iter 70, Step 20280, episodic return is 200.00. {'iteration': 70.0, 'performance': 200.0, 'ep_len': 200.0, 'ep_ret': 200.0, 'episode_len': 400.0, 'policy_loss': -1.6409, 'mean_log_prob': -0.4354, 'mean_advantage': 0.0, 'total_episodes': 201.0, 'total_timesteps': 20280.0}
# In 70 iteration, episodic return 200.000 is greater than reward threshold 195.0. Congratulation! Now we exit the training process.
# Environment is closed.

# %%
# Run this cell without modification

pg_result_no_na_df = pd.DataFrame(pg_result_no_na)
pg_result_na_df = pd.DataFrame(pg_result_na)
pg_result_no_na_df["normalize_advantage"] = False
pg_result_na_df["normalize_advantage"] = True

ax = sns.lineplot(
    x="total_timesteps", 
    y="performance", 
    data=pd.concat([pg_result_no_na_df, pg_result_na_df]).reset_index(), hue="normalize_advantage",
)
ax.set_title("Policy Gradient: Advantage normalization matters!")
# Out:
# Text(0.5, 1.0, 'Policy Gradient: Advantage normalization matters!')

# %% [markdown]
# ### Section 4.4: Train REINFORCE in MetaDrive-Easy

# %%
# Run this cell without modification

env_name = "MetaDrive-Tut-Easy-v0"

pg_trainer_metadrive_easy, pg_trainer_metadrive_easy_result = run(PGTrainer, dict(
    train_batch_size=2000,
    normalize_advantage=True,
    max_episode_length=200,
    max_iteration=5000,
    evaluate_interval=10,
    evaluate_num_episodes=10,
    learning_rate=0.001,
    clip_norm=10.0,
    env_name=env_name
), reward_threshold=120)


pg_trainer_metadrive_easy.save("pg_trainer_metadrive_easy.pt")
# Out:
# WARNING:root:BaseEngine is not launched, fail to sync seed to engine!
# :task(warning): Creating implicit AsyncTaskChain default for AsyncTaskManager TaskManager
# Num inputs: 259, Num actions: 9
# (6.2s,+6.2s) Iter 0, Step 2057, episodic return is 2.62. {'iteration': 0.0, 'performance': 1.9132, 'ep_len': 187.0, 'ep_ret': 1.9132, 'episode_len': 2057.0, 'success_rate': 0.0, 'policy_loss': -7.4004, 'mean_log_prob': -2.1943, 'mean_advantage': 0.0, 'total_episodes': 11.0, 'total_timesteps': 2057.0}
# (37.1s,+31.0s) Iter 10, Step 22189, episodic return is 6.06. {'iteration': 10.0, 'performance': 5.3912, 'ep_len': 201.0, 'ep_ret': 5.3912, 'episode_len': 2010.0, 'success_rate': 0.0, 'policy_loss': -44.802, 'mean_log_prob': -2.1098, 'mean_advantage': 0.0, 'total_episodes': 112.0, 'total_timesteps': 22189.0}
# (74.2s,+37.1s) Iter 20, Step 42973, episodic return is 10.31. {'iteration': 20.0, 'performance': 7.1516, 'ep_len': 167.75, 'ep_ret': 7.1516, 'episode_len': 2013.0, 'success_rate': 0.0, 'policy_loss': -1.1635, 'mean_log_prob': -1.8476, 'mean_advantage': -0.0, 'total_episodes': 227.0, 'total_timesteps': 42973.0}
# (109.6s,+35.4s) Iter 30, Step 63819, episodic return is 9.25. {'iteration': 30.0, 'performance': 16.2739, 'ep_len': 136.6, 'ep_ret': 16.2739, 'episode_len': 2049.0, 'success_rate': 0.0, 'policy_loss': -63.966, 'mean_log_prob': -1.7319, 'mean_advantage': 0.0, 'total_episodes': 357.0, 'total_timesteps': 63819.0}
# (149.2s,+39.6s) Iter 40, Step 84587, episodic return is 59.78. {'iteration': 40.0, 'performance': 51.7152, 'ep_len': 89.1304, 'ep_ret': 51.7152, 'episode_len': 2050.0, 'success_rate': 0.0435, 'policy_loss': -22.4751, 'mean_log_prob': -1.0496, 'mean_advantage': 0.0, 'total_episodes': 553.0, 'total_timesteps': 84587.0}
# (190.7s,+41.4s) Iter 50, Step 105046, episodic return is 106.65. {'iteration': 50.0, 'performance': 85.5199, 'ep_len': 85.1667, 'ep_ret': 85.5199, 'episode_len': 2044.0, 'success_rate': 0.4583, 'policy_loss': -54.7971, 'mean_log_prob': -0.278, 'mean_advantage': 0.0, 'total_episodes': 784.0, 'total_timesteps': 105046.0}
# (234.7s,+44.0s) Iter 60, Step 125531, episodic return is 125.49. {'iteration': 60.0, 'performance': 125.4805, 'ep_len': 98.0, 'ep_ret': 125.4805, 'episode_len': 2058.0, 'success_rate': 1.0, 'policy_loss': -25.3629, 'mean_log_prob': -0.0159, 'mean_advantage': 0.0, 'total_episodes': 1000.0, 'total_timesteps': 125531.0}
# In 60 iteration, episodic return 125.493 is greater than reward threshold 120. Congratulation! Now we exit the training process.
# Environment is closed.

# %%
# Run this cell without modification

# Render the learned behavior
# NOTE: The learned agent is marked by green color.
eval_reward, eval_info = evaluate(
    policy=pg_trainer_metadrive_easy.policy, 
    num_episodes=1, 
    env_name=pg_trainer_metadrive_easy.env_name,
    render="topdown",  # Visualize the behaviors in top-down view
    verbose=True
)

frames = [pygame.surfarray.array3d(f).swapaxes(0, 1) for f in eval_info["frames"]]

animate(frames)

print("REINFORCE agent achieves {} return in MetaDrive easy environment.".format(eval_reward))
# Out:
# REINFORCE agent achieves 125.58145966674864 return in MetaDrive easy environment.

# %% [markdown]
# ## Section 5: Policy gradient with baseline
#
# (20 / 100 points)
#
# We compute the gradient of $Q = \mathop{\mathbb E} \sum_t r(a_t, s_t)$ w.r.t. the parameter to update the policy. Let's consider this case: when you take a so-so action that lead to positive expected return, the policy gradient is also positive and you will update your network toward this action. At the same time a potential better action is ignored.
#
# To tackle this problem, we introduce the "baseline" when computing the policy gradient. The insight behind this is that we want to optimize the policy toward an action that are better than the "average action".
#
# We introduce $b_{t} = \mathbb E_{a_t} \sum_{t'}{\gamma^{t'-t} r(s_{t'}, a_{t'})}$ as the baseline. It average the expected discount return of all possible actions at state $s_t$. So that the "advantage" achieved by action $a_t$ can be evaluated via $\sum_{t'=t} \gamma^{t' -t}r(a_{t'}, s_{t'}) - b_t$
#
# Therefore, the policy gradient becomes:
#
# $$\nabla_\theta Q =\cfrac{1}{N}\sum_{i=1}^N [( \sum_t  \nabla_\theta \log \pi_\theta(a_{i,t}|s_{i,t}) (\sum_{t'} \gamma^{t'-t} r(s_{i,{t’}}, a_{i,t‘}) - b_{i, t})]$$
#
# In our implementation, we estimate the baseline via an extra network `self.baseline`, which has same structure of policy network but output only a scalar value. We use the output of this network to serve as the baseline, while this network is updated by fitting the true value of expected return of current state: $\mathbb E_{a_t} \sum_{t'}{\gamma^{t'-t} r(s_{t'}, a_{t'})}$
#
# The state-action values might have large variance if the reward function has large variance. It is not easy for a neural network to predict targets with large variance and extreme values. In implementation, we use a trick to match the distribution of baseline and values. During training, we first collect a batch of target values: $\{t_i= \mathbb E_{a_t} \sum_{t'}{\gamma^{t'-t} r(s_{t'}, a_{t'})}\}_i$. Then we normalize all targets to a standard distribution with mean = 0 and std = 1. Then we ask the baseline network to fit such normalized targets.
#
# When computing the advantages, instead of using the output of baseline network as the baseline $b$, we firstly match the baseline distribution with state-action values, that is we "de-standarize" the baselines. The transformed baselines $b' = f(b)$ should has the same mean and STD with the action values.
#
# After that, we compute the advantage of current action: $adv_{i,t} = \sum_{t'} \gamma^{t'-t} r(s_{i,{t'}}, a_{i,t'}) - b'_{i, t}$
#
# By doing this, we mitigate the instability of training baseline.
#
# Hint: We suggest to normalize an array via: `(x - x.mean()) / max(x.std(), 1e-6)`. The max term can mitigate numeraical instability.

# %% [markdown]
# ### Section 5.1: Build PG method with baseline

# %%
class PolicyGradientWithBaselineTrainer(PGTrainer):
    def initialize_parameters(self):
        # Build the actor in name of self.policy
        super().initialize_parameters()
        
        # Build the baseline network using Net class.
        self.baseline = PytorchModel(
            self.obs_dim, 1, self.config["hidden_units"]
        ).to(self.device)
        
        self.baseline_loss = nn.MSELoss()
            
        self.baseline_optimizer = torch.optim.Adam(
            self.baseline.parameters(),
            lr=self.config["learning_rate"]
        )

    def process_samples(self, samples):
        # Call the original process_samples function to get advantages
        tmp_samples, _ = super().process_samples(samples)
        values = tmp_samples["advantages"]
        samples["values"] = values  # We add q_values into samples

        # [TODO] flatten the observations in all trajectories (still a numpy array)
        obs = np.concatenate(tmp_samples["obs"])
        #pass
        
        assert obs.ndim == 2
        assert obs.shape[1] == self.obs_dim
        
        obs = self.to_tensor(obs)
        samples["flat_obs"] = obs

        # [TODO] Compute the baseline by feeding observation to baseline network
        # Hint: `baselines` is a numpy array with the same shape of `values`,
        #  that is: (batch size, )
        baselines = self.baseline(obs[None, :]).squeeze().reshape(values.shape).detach().numpy()
        
        assert baselines.shape == values.shape
        
        # [TODO] Match the distribution of baselines to the values.
        # Hint: We expect to see baselines.std() almost equals to values.std(), 
        #  and baselines.mean() almost equals to values.mean()
        baselines= (baselines - baselines.mean())/np.maximum(baselines.std(),1e-6)

        # Compute the advantage
        advantages = values - baselines
        samples["advantages"] = advantages
        process_info = {"mean_baseline": float(np.mean(baselines))}
        return samples, process_info

    def update_model(self, processed_samples):
        update_info = {}
        update_info.update(self.update_baseline(processed_samples))
        update_info.update(self.update_policy(processed_samples))
        return update_info

    def update_baseline(self, processed_samples):
        self.baseline.train()
        obs = processed_samples["flat_obs"]

        # [TODO] Normalize the values to mean=0, std=1.
        baselines= (baselines - baselines.mean()).np.maximum(baselines.std(),1e-6)
        
        values = processed_samples["values"]
             
        values = self.to_tensor(values[:, np.newaxis])
        
        baselines = self.baseline(obs)

        self.baseline_optimizer.zero_grad()
        loss = self.baseline_loss(input=baselines, target=values)
        loss.backward()
        
        # Clip the gradient
        torch.nn.utils.clip_grad_norm_(
            self.baseline.parameters(), self.config["clip_gradient"]
        )
        
        self.baseline_optimizer.step()
        self.baseline.eval()
        return dict(baseline_loss=loss.item())

# %% [markdown]
# ### Section 5.2: Run PG w/ baseline in CartPole

# %%
# Run this cell without modification

pg_trainer_wb_cartpole, pg_trainer_wb_cartpole_result = run(PolicyGradientWithBaselineTrainer, dict(
    learning_rate=0.01,
    max_episode_length=200,
    train_batch_size=200,
    
    env_name="CartPole-v0",
    normalize_advantage=True,
    
    evaluate_interval=10,
    evaluate_num_episodes=10,
), 195.0)
# Out:
# Num inputs: 4, Num actions: 2
# Num inputs: 4, Num actions: 1
# (0.2s,+0.2s) Iter 0, Step 238, episodic return is 15.30. {'iteration': 0.0, 'performance': 47.6, 'ep_len': 47.6, 'ep_ret': 47.6, 'episode_len': 238.0, 'mean_baseline': 0.0, 'policy_loss': -1.8541, 'mean_log_prob': -0.6974, 'mean_advantage': -0.0, 'total_episodes': 5.0, 'total_timesteps': 238.0}
# /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/ValenXie/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (0.9s,+0.7s) Iter 10, Step 2383, episodic return is 16.50. {'iteration': 10.0, 'performance': 18.8182, 'ep_len': 18.8182, 'ep_ret': 18.8182, 'episode_len': 207.0, 'mean_baseline': -0.0, 'policy_loss': 16.0404, 'mean_log_prob': -0.6507, 'mean_advantage': 0.0, 'total_episodes': 107.0, 'total_timesteps': 2383.0}
# (1.7s,+0.8s) Iter 20, Step 4608, episodic return is 61.40. {'iteration': 20.0, 'performance': 35.8333, 'ep_len': 35.8333, 'ep_ret': 35.8333, 'episode_len': 215.0, 'mean_baseline': 0.0, 'policy_loss': 20.3501, 'mean_log_prob': -0.6169, 'mean_advantage': 0.0, 'total_episodes': 182.0, 'total_timesteps': 4608.0}
# (2.6s,+0.9s) Iter 30, Step 6872, episodic return is 105.00. {'iteration': 30.0, 'performance': 62.5, 'ep_len': 62.5, 'ep_ret': 62.5, 'episode_len': 250.0, 'mean_baseline': -0.0, 'policy_loss': 57.2975, 'mean_log_prob': -0.4922, 'mean_advantage': 0.0, 'total_episodes': 215.0, 'total_timesteps': 6872.0}
# (3.7s,+1.1s) Iter 40, Step 9507, episodic return is 172.60. {'iteration': 40.0, 'performance': 151.0, 'ep_len': 151.0, 'ep_ret': 151.0, 'episode_len': 302.0, 'mean_baseline': -0.0, 'policy_loss': 1.7842, 'mean_log_prob': -0.4698, 'mean_advantage': -0.0, 'total_episodes': 242.0, 'total_timesteps': 9507.0}
# (5.3s,+1.6s) Iter 50, Step 13346, episodic return is 195.40. {'iteration': 50.0, 'performance': 200.0, 'ep_len': 200.0, 'ep_ret': 200.0, 'episode_len': 400.0, 'mean_baseline': -0.0, 'policy_loss': -13.4766, 'mean_log_prob': -0.3438, 'mean_advantage': 0.0, 'total_episodes': 262.0, 'total_timesteps': 13346.0}
# In 50 iteration, episodic return 195.400 is greater than reward threshold 195.0. Congratulation! Now we exit the training process.
# Environment is closed.

# %%
# Run this cell without modification

pg_result_no_na_df = pd.DataFrame(pg_result_no_na)
pg_result_no_na_df["normalize_advantage"] = "False"
pg_result_na_df = pd.DataFrame(pg_result_na)
pg_result_na_df["normalize_advantage"] = "True"
pg_trainer_wb_cartpole_result_df = pd.DataFrame(pg_trainer_wb_cartpole_result)
pg_trainer_wb_cartpole_result_df["normalize_advantage"] = "True with Baseline"
pg_result_df = pd.concat([pg_result_no_na_df, pg_result_na_df, pg_trainer_wb_cartpole_result_df]).reset_index()
ax = sns.lineplot(
    x="total_timesteps", 
    y="performance", 
    data=pg_result_df, hue="normalize_advantage",
)
ax.set_title("Policy Gradient")
# Out:
# Text(0.5, 1.0, 'Policy Gradient')

# %% [markdown]
# ### Section 5.3: Run PG w/ baseline in MetaDrive-Easy

# %%
# Run this cell without modification

env_name = "MetaDrive-Tut-Easy-v0"

pg_trainer_wb_metadrive_easy, pg_trainer_wb_metadrive_easy_result = run(
    PolicyGradientWithBaselineTrainer, 
    dict(
        train_batch_size=2000,
        normalize_advantage=True,
        max_episode_length=200,
        max_iteration=5000,
        evaluate_interval=10,
        evaluate_num_episodes=10,
        learning_rate=0.001,
        clip_norm=10.0,
        env_name=env_name
    ), 
    reward_threshold=120
)

pg_trainer_wb_metadrive_easy.save("pg_trainer_wb_metadrive_easy.pt")
# Out:
# WARNING:root:BaseEngine is not launched, fail to sync seed to engine!
# :task(warning): Creating implicit AsyncTaskChain default for AsyncTaskManager TaskManager
# Num inputs: 259, Num actions: 9
# Num inputs: 259, Num actions: 1
# (5.7s,+5.7s) Iter 0, Step 2010, episodic return is 3.16. {'iteration': 0.0, 'performance': 2.4182, 'ep_len': 201.0, 'ep_ret': 2.4182, 'episode_len': 2010.0, 'success_rate': 0.0, 'mean_baseline': -0.0, 'policy_loss': -6.0659, 'mean_log_prob': -2.1873, 'mean_advantage': 0.0, 'total_episodes': 10.0, 'total_timesteps': 2010.0}
# (37.3s,+31.6s) Iter 10, Step 22342, episodic return is 23.91. {'iteration': 10.0, 'performance': 12.3207, 'ep_len': 189.0, 'ep_ret': 12.3207, 'episode_len': 2079.0, 'success_rate': 0.0, 'mean_baseline': -0.0, 'policy_loss': -122.9657, 'mean_log_prob': -1.8321, 'mean_advantage': 0.0, 'total_episodes': 112.0, 'total_timesteps': 22342.0}
# (78.7s,+41.5s) Iter 20, Step 43083, episodic return is 73.97. {'iteration': 20.0, 'performance': 76.7276, 'ep_len': 90.4783, 'ep_ret': 76.7276, 'episode_len': 2081.0, 'success_rate': 0.1739, 'mean_baseline': -0.0, 'policy_loss': -82.7775, 'mean_log_prob': -0.5552, 'mean_advantage': 0.0, 'total_episodes': 299.0, 'total_timesteps': 43083.0}
# (121.1s,+42.4s) Iter 30, Step 63491, episodic return is 125.55. {'iteration': 30.0, 'performance': 125.5371, 'ep_len': 98.1905, 'ep_ret': 125.5371, 'episode_len': 2062.0, 'success_rate': 1.0, 'mean_baseline': -0.0, 'policy_loss': -44.6227, 'mean_log_prob': -0.0414, 'mean_advantage': 0.0, 'total_episodes': 519.0, 'total_timesteps': 63491.0}
# In 30 iteration, episodic return 125.547 is greater than reward threshold 120. Congratulation! Now we exit the training process.
# Environment is closed.

# %%
# Run this cell without modification

# Render the learned behavior
# NOTE: The learned agent is marked by green color.
eval_reward, eval_info = evaluate(
    policy=pg_trainer_wb_metadrive_easy.policy, 
    num_episodes=1, 
    env_name=pg_trainer_wb_metadrive_easy.env_name,
    render="topdown",  # Visualize the behaviors in top-down view
    verbose=True
)

frames = [pygame.surfarray.array3d(f).swapaxes(0, 1) for f in eval_info["frames"]]

animate(frames)

print("PG agent achieves {} return in MetaDrive easy environment.".format(eval_reward))
# Out:
# PG agent achieves 125.58145966674864 return in MetaDrive easy environment.

# %%
# Run this cell without modification

pg_trainer_wb_metadrive_easy_result_df = pd.DataFrame(pg_trainer_wb_metadrive_easy_result)
pg_trainer_wb_metadrive_easy_result_df["with Baseline"] = True


pg_trainer_metadrive_easy_result_df = pd.DataFrame(pg_trainer_metadrive_easy_result)
pg_trainer_metadrive_easy_result_df["with Baseline"] = False

ax = sns.lineplot(
    x="total_timesteps", 
    y="performance", 
    data=pd.concat([pg_trainer_wb_metadrive_easy_result_df, pg_trainer_metadrive_easy_result_df]).reset_index(), 
    hue="with Baseline",
)
ax.set_title("Policy Gradient in MetaDrive: Baseline matters!")
# Out:
# Text(0.5, 1.0, 'Policy Gradient in MetaDrive: Baseline matters!')

# %% [markdown]
# ### Section 5.4: Run PG with baseline in MetaDrive-Hard
#
# **Goal: Acheive episodic return > 50.**
#
# **BONUS!!** **can be earned if you can improve the training performance by adjusting hyper-parameters and optimizing code. Improvement means achieving > 0.0 success rate. However, I can't promise that it is feasible to use PG with or without algorithm to solve this task.** Please creates a independent markdown cell to highlight your improvement.

# %%
# Run this cell without modification

env_name = "MetaDrive-Tut-Hard-v0"

pg_trainer_wb_metadrive_hard, pg_trainer_wb_metadrive_hard_result = run(
    PolicyGradientWithBaselineTrainer, 
    dict(
        train_batch_size=4000,
        normalize_advantage=True,
        max_episode_length=1000,
        max_iteration=5000,
        evaluate_interval=10,
        evaluate_num_episodes=10,
        learning_rate=0.001,
        clip_norm=10.0,
        env_name=env_name
    ), 
    reward_threshold=120
)

pg_trainer_wb_metadrive_hard.save("pg_trainer_wb_metadrive_hard.pt")
# Out:
# WARNING:root:BaseEngine is not launched, fail to sync seed to engine!
# :task(warning): Creating implicit AsyncTaskChain default for AsyncTaskManager TaskManager
# Num inputs: 259, Num actions: 25
# Num inputs: 259, Num actions: 1
# (44.8s,+44.8s) Iter 0, Step 4912, episodic return is 10.08. {'iteration': 0.0, 'performance': 9.781, 'ep_len': 818.6667, 'ep_ret': 9.781, 'episode_len': 4912.0, 'success_rate': 0.0, 'mean_baseline': 0.0, 'policy_loss': 6.3351, 'mean_log_prob': -3.2111, 'mean_advantage': -0.0, 'total_episodes': 6.0, 'total_timesteps': 4912.0}
# (200.7s,+156.0s) Iter 10, Step 49835, episodic return is 22.39. {'iteration': 10.0, 'performance': 19.16, 'ep_len': 839.8, 'ep_ret': 19.16, 'episode_len': 4199.0, 'success_rate': 0.0, 'mean_baseline': 0.0, 'policy_loss': -67.8867, 'mean_log_prob': -3.0838, 'mean_advantage': -0.0, 'total_episodes': 56.0, 'total_timesteps': 49835.0}
# (352.9s,+152.2s) Iter 20, Step 92410, episodic return is 8.65. {'iteration': 20.0, 'performance': 15.8081, 'ep_len': 409.5455, 'ep_ret': 15.8081, 'episode_len': 4505.0, 'success_rate': 0.0, 'mean_baseline': 0.0, 'policy_loss': 73.2358, 'mean_log_prob': -2.6884, 'mean_advantage': -0.0, 'total_episodes': 135.0, 'total_timesteps': 92410.0}
# (511.7s,+158.8s) Iter 30, Step 134961, episodic return is 14.19. {'iteration': 30.0, 'performance': 16.0649, 'ep_len': 255.4375, 'ep_ret': 16.0649, 'episode_len': 4087.0, 'success_rate': 0.0, 'mean_baseline': 0.0, 'policy_loss': -113.2018, 'mean_log_prob': -2.3431, 'mean_advantage': -0.0, 'total_episodes': 272.0, 'total_timesteps': 134961.0}
# (671.2s,+159.5s) Iter 40, Step 176435, episodic return is 13.63. {'iteration': 40.0, 'performance': 15.3865, 'ep_len': 169.9167, 'ep_ret': 15.3865, 'episode_len': 4078.0, 'success_rate': 0.0417, 'mean_baseline': -0.0, 'policy_loss': 132.9773, 'mean_log_prob': -2.1067, 'mean_advantage': 0.0, 'total_episodes': 459.0, 'total_timesteps': 176435.0}
# (818.4s,+147.2s) Iter 50, Step 217812, episodic return is 10.80. {'iteration': 50.0, 'performance': 12.1947, 'ep_len': 132.0323, 'ep_ret': 12.1947, 'episode_len': 4093.0, 'success_rate': 0.0, 'mean_baseline': -0.0, 'policy_loss': -95.7114, 'mean_log_prob': -2.0144, 'mean_advantage': 0.0, 'total_episodes': 720.0, 'total_timesteps': 217812.0}
# (979.4s,+161.0s) Iter 60, Step 259736, episodic return is 15.21. {'iteration': 60.0, 'performance': 12.7625, 'ep_len': 109.2821, 'ep_ret': 12.7625, 'episode_len': 4262.0, 'success_rate': 0.0, 'mean_baseline': -0.0, 'policy_loss': 249.6632, 'mean_log_prob': -1.9862, 'mean_advantage': 0.0, 'total_episodes': 1043.0, 'total_timesteps': 259736.0}
# (1135.7s,+156.3s) Iter 70, Step 300520, episodic return is 25.47. {'iteration': 70.0, 'performance': 10.2588, 'ep_len': 108.4324, 'ep_ret': 10.2588, 'episode_len': 4012.0, 'success_rate': 0.0, 'mean_baseline': 0.0, 'policy_loss': -126.8882, 'mean_log_prob': -1.967, 'mean_advantage': -0.0, 'total_episodes': 1379.0, 'total_timesteps': 300520.0}
# (1296.3s,+160.5s) Iter 80, Step 341708, episodic return is 14.61. {'iteration': 80.0, 'performance': 16.3537, 'ep_len': 170.625, 'ep_ret': 16.3537, 'episode_len': 4095.0, 'success_rate': 0.0, 'mean_baseline': -0.0, 'policy_loss': 171.6128, 'mean_log_prob': -1.854, 'mean_advantage': 0.0, 'total_episodes': 1682.0, 'total_timesteps': 341708.0}
# (1451.7s,+155.5s) Iter 90, Step 383212, episodic return is 14.91. {'iteration': 90.0, 'performance': 8.5315, 'ep_len': 104.5385, 'ep_ret': 8.5315, 'episode_len': 4077.0, 'success_rate': 0.0, 'mean_baseline': 0.0, 'policy_loss': -61.3777, 'mean_log_prob': -1.779, 'mean_advantage': -0.0, 'total_episodes': 1995.0, 'total_timesteps': 383212.0}
# (1603.4s,+151.6s) Iter 100, Step 423850, episodic return is 5.32. {'iteration': 100.0, 'performance': 11.5417, 'ep_len': 115.1143, 'ep_ret': 11.5417, 'episode_len': 4029.0, 'success_rate': 0.0286, 'mean_baseline': 0.0, 'policy_loss': 74.7527, 'mean_log_prob': -1.6546, 'mean_advantage': -0.0, 'total_episodes': 2339.0, 'total_timesteps': 423850.0}
# (1757.8s,+154.4s) Iter 110, Step 465100, episodic return is 20.02. {'iteration': 110.0, 'performance': 11.9399, 'ep_len': 126.5312, 'ep_ret': 11.9399, 'episode_len': 4049.0, 'success_rate': 0.0, 'mean_baseline': -0.0, 'policy_loss': -71.7139, 'mean_log_prob': -1.7059, 'mean_advantage': 0.0, 'total_episodes': 2679.0, 'total_timesteps': 465100.0}
# (1908.2s,+150.4s) Iter 120, Step 505969, episodic return is 8.61. {'iteration': 120.0, 'performance': 9.0572, 'ep_len': 113.75, 'ep_ret': 9.0572, 'episode_len': 4095.0, 'success_rate': 0.0, 'mean_baseline': -0.0, 'policy_loss': 178.7828, 'mean_log_prob': -1.85, 'mean_advantage': 0.0, 'total_episodes': 2996.0, 'total_timesteps': 505969.0}
# (2069.5s,+161.3s) Iter 130, Step 547727, episodic return is 16.90. {'iteration': 130.0, 'performance': 18.5848, 'ep_len': 183.6087, 'ep_ret': 18.5848, 'episode_len': 4223.0, 'success_rate': 0.0, 'mean_baseline': -0.0, 'policy_loss': -27.3681, 'mean_log_prob': -1.8734, 'mean_advantage': 0.0, 'total_episodes': 3259.0, 'total_timesteps': 547727.0}
# (2232.5s,+163.0s) Iter 140, Step 589457, episodic return is 21.78. {'iteration': 140.0, 'performance': 20.1889, 'ep_len': 232.3333, 'ep_ret': 20.1889, 'episode_len': 4182.0, 'success_rate': 0.0, 'mean_baseline': 0.0, 'policy_loss': -5.7004, 'mean_log_prob': -1.694, 'mean_advantage': -0.0, 'total_episodes': 3472.0, 'total_timesteps': 589457.0}
# (2390.0s,+157.5s) Iter 150, Step 630899, episodic return is 20.27. {'iteration': 150.0, 'performance': 22.6968, 'ep_len': 230.7, 'ep_ret': 22.6968, 'episode_len': 4614.0, 'success_rate': 0.0, 'mean_baseline': 0.0, 'policy_loss': 11.6438, 'mean_log_prob': -1.6971, 'mean_advantage': -0.0, 'total_episodes': 3736.0, 'total_timesteps': 630899.0}
# (2542.3s,+152.3s) Iter 160, Step 671851, episodic return is 9.00. {'iteration': 160.0, 'performance': 11.7491, 'ep_len': 119.2941, 'ep_ret': 11.7491, 'episode_len': 4056.0, 'success_rate': 0.0, 'mean_baseline': 0.0, 'policy_loss': -19.5919, 'mean_log_prob': -1.7231, 'mean_advantage': -0.0, 'total_episodes': 4008.0, 'total_timesteps': 671851.0}
# (2695.2s,+152.9s) Iter 170, Step 712739, episodic return is 8.87. {'iteration': 170.0, 'performance': 13.0728, 'ep_len': 110.4211, 'ep_ret': 13.0728, 'episode_len': 4196.0, 'success_rate': 0.0, 'mean_baseline': -0.0, 'policy_loss': -121.6573, 'mean_log_prob': -1.7368, 'mean_advantage': 0.0, 'total_episodes': 4315.0, 'total_timesteps': 712739.0}
# (2847.1s,+151.9s) Iter 180, Step 753451, episodic return is 7.52. {'iteration': 180.0, 'performance': 14.4594, 'ep_len': 94.3023, 'ep_ret': 14.4594, 'episode_len': 4055.0, 'success_rate': 0.0233, 'mean_baseline': 0.0, 'policy_loss': 14.4443, 'mean_log_prob': -1.7755, 'mean_advantage': -0.0, 'total_episodes': 4717.0, 'total_timesteps': 753451.0}
# (3005.5s,+158.4s) Iter 190, Step 794039, episodic return is 11.59. {'iteration': 190.0, 'performance': 15.5466, 'ep_len': 87.0652, 'ep_ret': 15.5466, 'episode_len': 4005.0, 'success_rate': 0.0, 'mean_baseline': -0.0, 'policy_loss': 31.5588, 'mean_log_prob': -1.7837, 'mean_advantage': 0.0, 'total_episodes': 5178.0, 'total_timesteps': 794039.0}
# (3162.8s,+157.3s) Iter 200, Step 834361, episodic return is 12.32. {'iteration': 200.0, 'performance': 13.5539, 'ep_len': 82.102, 'ep_ret': 13.5539, 'episode_len': 4023.0, 'success_rate': 0.0, 'mean_baseline': -0.0, 'policy_loss': -119.068, 'mean_log_prob': -1.9068, 'mean_advantage': 0.0, 'total_episodes': 5669.0, 'total_timesteps': 834361.0}
# (3318.3s,+155.5s) Iter 210, Step 875019, episodic return is 11.24. {'iteration': 210.0, 'performance': 19.0329, 'ep_len': 108.2703, 'ep_ret': 19.0329, 'episode_len': 4006.0, 'success_rate': 0.0, 'mean_baseline': -0.0, 'policy_loss': -17.8758, 'mean_log_prob': -2.1523, 'mean_advantage': 0.0, 'total_episodes': 6122.0, 'total_timesteps': 875019.0}
# Environment is closed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/18/mc_7692d7c9665mhcdrpp2v00000gn/T/ipykernel_37004/3890468693.py in <module>
#      16         env_name=env_name
#      17     ),
# ---> 18     reward_threshold=120
#      19 )
#      20
#
# /var/folders/18/mc_7692d7c9665mhcdrpp2v00000gn/T/ipykernel_37004/2476927539.py in run(trainer_cls, config, reward_threshold)
#      18     try:
#      19         for i in range(config['max_iteration'] + 1):
# ---> 20             stat = trainer.train()
#      21             stat = stat or {}
#      22             stats.append(stat)
#
# /var/folders/18/mc_7692d7c9665mhcdrpp2v00000gn/T/ipykernel_37004/369799049.py in train(self)
#     264
#     265         # Collect samples
# --> 266         samples, sample_info = self.collect_samples()
#     267         info.update(sample_info)
#     268
#
# /var/folders/18/mc_7692d7c9665mhcdrpp2v00000gn/T/ipykernel_37004/369799049.py in collect_samples(self)
#     185                 # print("ACT: ", act, type(act))
#     186
# --> 187                 next_obs, reward, done, step_info = self.env.step(act)
#     188
#     189                 obs_list.append(obs)
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/gym/core.py in step(self, action)
#     246
#     247     def step(self, action):
# --> 248         return self.env.step(action)
#     249
#     250     def reset(self, **kwargs):
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/metadrive/envs/base_env.py in step(self, actions)
#     245         actions = self._preprocess_actions(actions)
#     246         engine_info = self._step_simulator(actions)
# --> 247         o, r, d, i = self._get_step_return(actions, engine_info=engine_info)
#     248         return o, r, d, i
#     249
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/metadrive/envs/base_env.py in _get_step_return(self, actions, engine_info)
#     372             done = done_function_result or self.dones[v_id]
#     373             self.dones[v_id] = done
# --> 374             o = self.observations[v_id].observe(v)
#     375             obses[v_id] = o
#     376
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/metadrive/obs/state_obs.py in observe(self, vehicle)
#     170         """
#     171         state = self.state_observe(vehicle)
# --> 172         other_v_info = self.lidar_observe(vehicle)
#     173         self.current_observation = np.concatenate((state, np.asarray(other_v_info)))
#     174         ret = self.current_observation
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/metadrive/obs/state_obs.py in lidar_observe(self, vehicle)
#     190                 cloud_points,
#     191                 gaussian_noise=self.config["lidar"]["gaussian_noise"],
# --> 192                 dropout_prob=self.config["lidar"]["dropout_prob"]
#     193             )
#     194             self.cloud_points = cloud_points
#
# ~/opt/anaconda3/envs/cs269/lib/python3.7/site-packages/metadrive/obs/state_obs.py in _add_noise_to_cloud_points(self, points, gaussian_noise, dropout_prob)
#     206             points[np.random.uniform(0, 1, size=points.shape) < dropout_prob] = 0.0
#     207
# --> 208         return list(points)
#
# KeyboardInterrupt:

# %%
# Run this cell without modification

# Render the learned behavior
# NOTE: The learned agent is marked by green color.
eval_reward, eval_info = evaluate(
    policy=pg_trainer_wb_metadrive_hard.policy, 
    num_episodes=1, 
    env_name=pg_trainer_wb_metadrive_hard.env_name,
    render="topdown",  # Visualize the behaviors in top-down view
    verbose=True
)

frames = [pygame.surfarray.array3d(f).swapaxes(0, 1) for f in eval_info["frames"]]

animate(frames)

print("PG agent achieves {} return in MetaDrive hard environment.".format(eval_reward))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/18/mc_7692d7c9665mhcdrpp2v00000gn/T/ipykernel_37004/2822944227.py in <module>
#       4 # NOTE: The learned agent is marked by green color.
#       5 eval_reward, eval_info = evaluate(
# ----> 6     policy=pg_trainer_wb_metadrive_hard.policy,
#       7     num_episodes=1,
#       8     env_name=pg_trainer_wb_metadrive_hard.env_name,
#
# NameError: name 'pg_trainer_wb_metadrive_hard' is not defined

# %% [markdown]
# ------
#
# ## Conclusion and Discussion
#
# In this assignment, we learn how to build naive Q learning, Deep Q Network and Policy Gradient methods.
#
# In the next markdown cell, you can write whatever you like. Like the suggestion on the course, the confusing problems in the assignments, and so on.
#
# If you want to do more investigation, feel free to open new cells via `Esc + B` after the next cells and write codes in it, so that you can reuse some result in this notebook. Remember to write sufficient comments and documents to let others know what you are doing.
#
# Following the submission instruction in the assignment to submit your assignment. Thank you!
#
# ------

# %%
'I couldn not finish running PG with baseline in MetaDrive-Hard so I think that is why when render the learned behavior it returns name pg_trainer_wb_metadrive_hard is not defined'
# Out:
# 'I couldn not finish running PG with baseline in MetaDrive-Hard so I think that is why when render the learned behavior it returns name pg_trainer_wb_metadrive_hard is not defined'
